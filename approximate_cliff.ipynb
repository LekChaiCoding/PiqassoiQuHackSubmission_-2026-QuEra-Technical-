# %%
import cirq
import numpy as np
from typing import List, Tuple

def bloch_state_to_unitary(theta: float, phi: float) -> np.ndarray:
    """
    Convert Bloch sphere angles to the unitary that rotates |0⟩ to |θ,φ⟩.
    
    The state |θ,φ⟩ = cos(θ/2)|0⟩ + e^(iφ)sin(θ/2)|1⟩
    """
    # This is simply Rz(phi) @ Ry(theta)
    return np.array([
        [np.cos(theta/2), -np.sin(theta/2)],
        [np.exp(1j*phi)*np.sin(theta/2), np.exp(1j*phi)*np.cos(theta/2)]
    ])

def find_best_clifford_t_approximation(angle: float, max_depth: int = 10) -> List[cirq.Gate]:
    """
    Find the best Clifford+T approximation for Rz(angle).
    Uses the fact that T = Rz(π/4) and S = Rz(π/2).
    """
    # T gate: e^(iπ/8) Rz(π/4)
    # We want to find k such that k*π/4 ≈ angle (mod 2π)
    
    # Normalize angle to [0, 2π)
    angle = angle % (2 * np.pi)
    
    # Find best approximation using denominator 2^max_depth
    denominator = 2 ** max_depth
    
    # Find k such that k * 2π / denominator ≈ angle
    k = round(angle * denominator / (2 * np.pi))
    k = k % denominator
    
    # Now express k in base 2 to minimize gates
    # We build the rotation from T and S gates
    gates = []
    
    # Convert k to a sum of powers of 2
    # Each T gate contributes π/4, each S contributes π/2
    # We want k * (2π / 2^max_depth) = k * π / 2^(max_depth-1)
    
    # Simplify: express in terms of π/4 units
    # k * (2π / 2^max_depth) = (k / 2^(max_depth-3)) * π/4
    
    n_units = k * (2 ** (3 - max_depth))  # Number of π/4 rotations
    n_units = round(n_units * (2 ** (max_depth - 3)))
    
    # Optimize using S gates (S = T^2)
    # Count in units of π/4
    total_quarter_turns = k % (denominator)
    
    # Express in minimal form
    # π/2 = 2 * π/4, so use S when possible
    n_half_turns = (total_quarter_turns * 8 // denominator) % 4
    remaining = (total_quarter_turns * 8 % denominator)
    
    n_quarter_turns = (remaining * 2 // denominator) % 2
    
    # Add S gates (Rz(π/2))
    for _ in range(n_half_turns):
        gates.append(cirq.S)
    
    # Add T gates (Rz(π/4))
    for _ in range(n_quarter_turns):
        gates.append(cirq.T)
    
    return gates

def create_bloch_state_clifford_t_simple(theta: float, phi: float, max_depth: int = 10) -> cirq.Circuit:
    """
    Create a circuit that prepares |θ,φ⟩ = Rz(φ) Ry(θ) |0⟩
    using a straightforward decomposition.
    """
    qubit = cirq.LineQubit(0)
    circuit = cirq.Circuit()
    
    # Strategy: Use exact Ry(theta) and approximate Rz(phi)
    # OR: Approximate both rotations
    
    # For better results, let's use Cirq's optimizer with Clifford+T gateset
    # First create the ideal circuit
    circuit.append(cirq.ry(theta)(qubit))
    circuit.append(cirq.rz(phi)(qubit))
    
    return circuit

def create_bloch_state_with_decomposition(theta: float, phi: float, 
                                          t_count: int = 10) -> cirq.Circuit:
    """
    Better approach: Use Cirq's built-in gate compilation to Clifford+T.
    
    Args:
        theta: Polar angle
        phi: Azimuthal angle  
        t_count: Approximate number of T gates to use (controls precision)
    """
    qubit = cirq.LineQubit(0)
    
    # Create ideal circuit
    ideal_circuit = cirq.Circuit()
    ideal_circuit.append(cirq.ry(theta)(qubit))
    ideal_circuit.append(cirq.rz(phi)(qubit))
    
    # Use Cirq's compiler to convert to specific gateset
    # Define Clifford+T gateset
    gateset = cirq.Gateset(cirq.H, cirq.S, cirq.T, cirq.CNOT, cirq.X, cirq.Y, cirq.Z)
    
    # Compile the circuit - this uses Solovay-Kitaev internally
    try:
        compiled = cirq.optimize_for_target_gateset(
            ideal_circuit,
            gateset=gateset,
            max_num_passes=5
        )
        return compiled
    except:
        # If compilation fails, use manual decomposition
        return manual_clifford_t_decomposition(theta, phi, t_count)

def manual_clifford_t_decomposition(theta: float, phi: float, precision_bits: int = 8) -> cirq.Circuit:
    """
    Manual decomposition with better approximation.
    """
    qubit = cirq.LineQubit(0)
    circuit = cirq.Circuit()
    
    # Decompose Ry(theta) into Clifford+T
    # Use: Ry(θ) = Rz(-π/2) Rx(θ) Rz(π/2) and Rx(θ) = H Rz(θ) H
    
    # First, apply Ry(theta)
    # Ry can be expressed as: S† H S† Rz(θ) S H S
    # But simpler: just use H and Rz
    
    # Approximate Ry(theta):
    # Ry(θ) ≈ H Rz(θ) H (not exact, but close for small theta)
    # Better: Ry(θ) = exp(iπ/4 Y) exp(-iπ/4 X) Rz(θ) exp(iπ/4 X) exp(-iπ/4 Y)
    
    # Even better: use the circuit Rz(φ/2) Rx(θ) Rz(φ/2 + π/2)
    # Where Rx(θ) = H Rz(θ) H
    
    # Most straightforward for Bloch state:
    # |θ,φ⟩ requires: First Ry(θ), then Rz(φ)
    
    # Ry(θ) using Clifford+H+Rz:
    circuit.append(cirq.S(qubit) ** -1)  # Rz(-π/2)
    circuit.append(cirq.H(qubit))
    
    # Approximate Rz(θ) with T gates
    rz_gates = approximate_rz_with_precision(theta, precision_bits)
    for gate in rz_gates:
        circuit.append(gate(qubit))
    
    circuit.append(cirq.H(qubit))
    circuit.append(cirq.S(qubit))  # Rz(π/2)
    
    # Now apply Rz(φ)
    rz_phi_gates = approximate_rz_with_precision(phi, precision_bits)
    for gate in rz_phi_gates:
        circuit.append(gate(qubit))
    
    return circuit

def approximate_rz_with_precision(angle: float, precision_bits: int) -> List[cirq.Gate]:
    """
    Approximate Rz(angle) using T and S gates.
    precision_bits controls accuracy: higher = more accurate
    """
    gates = []
    
    # Normalize to [0, 2π)
    angle = angle % (2 * np.pi)
    
    # Discretize: we can make rotations of 2π/2^n where n is precision
    n_steps = 2 ** precision_bits
    step_size = 2 * np.pi / n_steps
    
    # Find closest multiple
    n = round(angle / step_size) % n_steps
    
    # Express n in terms of T (π/4) and S (π/2) gates
    # Each step is 2π/2^precision_bits = π/2^(precision_bits-1)
    
    # T gate = Rz(π/4) = Rz(2π/8)
    # S gate = Rz(π/2) = Rz(2π/4)
    
    # We want n * (2π / 2^precision_bits)
    # Express as multiples of π/4
    
    quarter_turns = (n * 8) // n_steps
    
    # Use S and T optimally
    half_turns = quarter_turns // 2
    remaining_quarter = quarter_turns % 2
    
    # Optimize S gates (mod 4 since 4*S = I up to global phase)
    half_turns = half_turns % 4
    
    for _ in range(half_turns):
        gates.append(cirq.S)
    for _ in range(remaining_quarter):
        gates.append(cirq.T)
    
    return gates

# Example usage
if __name__ == "__main__":
    for theta in np.arange(0,np.pi,0.1):
        for phi in np.arange(0,np.pi,0.1):
            
            print(f"Creating Bloch sphere state |θ={theta:.4f}, φ={phi:.4f}⟩")
            #print(f"State: cos({theta/2:.4f})|0⟩ + e^(i*{phi:.4f})sin({theta/2:.4f})|1⟩\n")
            
            # Target state
            target_state = np.array([
                np.cos(theta/2),
                np.exp(1j * phi) * np.sin(theta/2)
            ])
            
            #print("Target state:", target_state)
            #print()
            
            # Try different precision levels
            for precision in [25]:
                #print(f"\n{'='*60}")
                #print(f"Precision bits = {precision}")
                #print(f"{'='*60}")
                
                circuit = manual_clifford_t_decomposition(theta, phi, precision_bits=precision)
                
                #print(f"Total gates: {len(circuit)}")
                
                # Count T gates
                t_count = sum(1 for moment in circuit for op in moment 
                            if op.gate == cirq.T or (isinstance(op.gate, cirq.ZPowGate) and abs(op.gate.exponent - 0.25) < 1e-10))
                #print(f"T-count: {t_count}")
                
                # Simulate
                simulator = cirq.Simulator()
                result = simulator.simulate(circuit)
                
                fidelity = abs(np.dot(np.conj(target_state), result.final_state_vector))**2
                print(f"Fidelity: {fidelity:.10f}")
                
                #print("\nCircuit:")
                #print(circuit)
                #print("\nFinal state:", result.final_state_vector)
# Out:
# Creating Bloch sphere state |θ=0.0000, φ=0.0000⟩
# Fidelity: 1.0000000000
# Creating Bloch sphere state |θ=0.0000, φ=0.1000⟩
# Fidelity: 1.0000000000
# Creating Bloch sphere state |θ=0.0000, φ=0.2000⟩
# Fidelity: 1.0000000000
# Creating Bloch sphere state |θ=0.0000, φ=0.3000⟩
# Fidelity: 1.0000000000
# Creating Bloch sphere state |θ=0.0000, φ=0.4000⟩
# Fidelity: 1.0000000000
# Creating Bloch sphere state |θ=0.0000, φ=0.5000⟩
# Fidelity: 1.0000000000
# Creating Bloch sphere state |θ=0.0000, φ=0.6000⟩
# Fidelity: 1.0000000000
# Creating Bloch sphere state |θ=0.0000, φ=0.7000⟩
# Fidelity: 1.0000000000
# Creating Bloch sphere state |θ=0.0000, φ=0.8000⟩
# Fidelity: 1.0000000000
# Creating Bloch sphere state |θ=0.0000, φ=0.9000⟩
# Fidelity: 1.0000000000
# Creating Bloch sphere state |θ=0.0000, φ=1.0000⟩
# Fidelity: 1.0000000000
# Creating Bloch sphere state |θ=0.0000, φ=1.1000⟩
# Fidelity: 1.0000000000
# Creating Bloch sphere state |θ=0.0000, φ=1.2000⟩
# Fidelity: 1.0000000000
# Creating Bloch sphere state |θ=0.0000, φ=1.3000⟩
# Fidelity: 1.0000000000
# Creating Bloch sphere state |θ=0.0000, φ=1.4000⟩
# Fidelity: 1.0000000000
# Creating Bloch sphere state |θ=0.0000, φ=1.5000⟩
# Fidelity: 1.0000000000
# Creating Bloch sphere state |θ=0.0000, φ=1.6000⟩
# Fidelity: 1.0000000000
# Creating Bloch sphere state |θ=0.0000, φ=1.7000⟩
# Fidelity: 1.0000000000
# Creating Bloch sphere state |θ=0.0000, φ=1.8000⟩
# Fidelity: 1.0000000000
# Creating Bloch sphere state |θ=0.0000, φ=1.9000⟩
# Fidelity: 1.0000000000
# Creating Bloch sphere state |θ=0.0000, φ=2.0000⟩
# Fidelity: 1.0000000000
# Creating Bloch sphere state |θ=0.0000, φ=2.1000⟩
# Fidelity: 1.0000000000
# Creating Bloch sphere state |θ=0.0000, φ=2.2000⟩
# Fidelity: 1.0000000000
# Creating Bloch sphere state |θ=0.0000, φ=2.3000⟩
# Fidelity: 1.0000000000
# Creating Bloch sphere state |θ=0.0000, φ=2.4000⟩
# Fidelity: 1.0000000000
# Creating Bloch sphere state |θ=0.0000, φ=2.5000⟩
# Fidelity: 1.0000000000
# Creating Bloch sphere state |θ=0.0000, φ=2.6000⟩
# Fidelity: 1.0000000000
# Creating Bloch sphere state |θ=0.0000, φ=2.7000⟩
# Fidelity: 1.0000000000
# Creating Bloch sphere state |θ=0.0000, φ=2.8000⟩
# Fidelity: 1.0000000000
# Creating Bloch sphere state |θ=0.0000, φ=2.9000⟩
# Fidelity: 1.0000000000
# Creating Bloch sphere state |θ=0.0000, φ=3.0000⟩
# Fidelity: 1.0000000000
# Creating Bloch sphere state |θ=0.0000, φ=3.1000⟩
# Fidelity: 1.0000000000
# Creating Bloch sphere state |θ=0.1000, φ=0.0000⟩
# Fidelity: 0.9975020826
# Creating Bloch sphere state |θ=0.1000, φ=0.1000⟩
# Fidelity: 0.9975020826
# Creating Bloch sphere state |θ=0.1000, φ=0.2000⟩
# Fidelity: 0.9975020826
# Creating Bloch sphere state |θ=0.1000, φ=0.3000⟩
# Fidelity: 0.9975020826
# Creating Bloch sphere state |θ=0.1000, φ=0.4000⟩
# Fidelity: 0.9975020826
# Creating Bloch sphere state |θ=0.1000, φ=0.5000⟩
# Fidelity: 0.9975020826
# Creating Bloch sphere state |θ=0.1000, φ=0.6000⟩
# Fidelity: 0.9975020826
# Creating Bloch sphere state |θ=0.1000, φ=0.7000⟩
# Fidelity: 0.9975020826
# Creating Bloch sphere state |θ=0.1000, φ=0.8000⟩
# Fidelity: 0.9975020826
# Creating Bloch sphere state |θ=0.1000, φ=0.9000⟩
# Fidelity: 0.9975020826
# Creating Bloch sphere state |θ=0.1000, φ=1.0000⟩
# Fidelity: 0.9975020826
# Creating Bloch sphere state |θ=0.1000, φ=1.1000⟩
# Fidelity: 0.9975020826
# Creating Bloch sphere state |θ=0.1000, φ=1.2000⟩
# Fidelity: 0.9975020826
# Creating Bloch sphere state |θ=0.1000, φ=1.3000⟩
# Fidelity: 0.9975020826
# Creating Bloch sphere state |θ=0.1000, φ=1.4000⟩
# Fidelity: 0.9975020826
# Creating Bloch sphere state |θ=0.1000, φ=1.5000⟩
# Fidelity: 0.9975020826
# Creating Bloch sphere state |θ=0.1000, φ=1.6000⟩
# Fidelity: 0.9975020826
# Creating Bloch sphere state |θ=0.1000, φ=1.7000⟩
# Fidelity: 0.9975020826
# Creating Bloch sphere state |θ=0.1000, φ=1.8000⟩
# Fidelity: 0.9975020826
# Creating Bloch sphere state |θ=0.1000, φ=1.9000⟩
# Fidelity: 0.9975020826
# Creating Bloch sphere state |θ=0.1000, φ=2.0000⟩
# Fidelity: 0.9975020826
# Creating Bloch sphere state |θ=0.1000, φ=2.1000⟩
# Fidelity: 0.9975020826
# Creating Bloch sphere state |θ=0.1000, φ=2.2000⟩
# Fidelity: 0.9975020826
# Creating Bloch sphere state |θ=0.1000, φ=2.3000⟩
# Fidelity: 0.9975020826
# Creating Bloch sphere state |θ=0.1000, φ=2.4000⟩
# Fidelity: 0.9975020826
# Creating Bloch sphere state |θ=0.1000, φ=2.5000⟩
# Fidelity: 0.9975020826
# Creating Bloch sphere state |θ=0.1000, φ=2.6000⟩
# Fidelity: 0.9975020826
# Creating Bloch sphere state |θ=0.1000, φ=2.7000⟩
# Fidelity: 0.9975020826
# Creating Bloch sphere state |θ=0.1000, φ=2.8000⟩
# Fidelity: 0.9975020826
# Creating Bloch sphere state |θ=0.1000, φ=2.9000⟩
# Fidelity: 0.9975020826
# Creating Bloch sphere state |θ=0.1000, φ=3.0000⟩
# Fidelity: 0.9975020826
# Creating Bloch sphere state |θ=0.1000, φ=3.1000⟩
# Fidelity: 0.9975020826
# Creating Bloch sphere state |θ=0.2000, φ=0.0000⟩
# Fidelity: 0.9900332889
# Creating Bloch sphere state |θ=0.2000, φ=0.1000⟩
# Fidelity: 0.9900332889
# Creating Bloch sphere state |θ=0.2000, φ=0.2000⟩
# Fidelity: 0.9900332889
# Creating Bloch sphere state |θ=0.2000, φ=0.3000⟩
# Fidelity: 0.9900332889
# Creating Bloch sphere state |θ=0.2000, φ=0.4000⟩
# Fidelity: 0.9900332889
# Creating Bloch sphere state |θ=0.2000, φ=0.5000⟩
# Fidelity: 0.9900332889
# Creating Bloch sphere state |θ=0.2000, φ=0.6000⟩
# Fidelity: 0.9900332889
# Creating Bloch sphere state |θ=0.2000, φ=0.7000⟩
# Fidelity: 0.9900332889
# Creating Bloch sphere state |θ=0.2000, φ=0.8000⟩
# Fidelity: 0.9900332889
# Creating Bloch sphere state |θ=0.2000, φ=0.9000⟩
# Fidelity: 0.9900332889
# Creating Bloch sphere state |θ=0.2000, φ=1.0000⟩
# Fidelity: 0.9900332889
# Creating Bloch sphere state |θ=0.2000, φ=1.1000⟩
# Fidelity: 0.9900332889
# Creating Bloch sphere state |θ=0.2000, φ=1.2000⟩
# Fidelity: 0.9900332889
# Creating Bloch sphere state |θ=0.2000, φ=1.3000⟩
# Fidelity: 0.9900332889
# Creating Bloch sphere state |θ=0.2000, φ=1.4000⟩
# Fidelity: 0.9900332889
# Creating Bloch sphere state |θ=0.2000, φ=1.5000⟩
# Fidelity: 0.9900332889
# Creating Bloch sphere state |θ=0.2000, φ=1.6000⟩
# Fidelity: 0.9900332889
# Creating Bloch sphere state |θ=0.2000, φ=1.7000⟩
# Fidelity: 0.9900332889
# Creating Bloch sphere state |θ=0.2000, φ=1.8000⟩
# Fidelity: 0.9900332889
# Creating Bloch sphere state |θ=0.2000, φ=1.9000⟩
# Fidelity: 0.9900332889
# Creating Bloch sphere state |θ=0.2000, φ=2.0000⟩
# Fidelity: 0.9900332889
# Creating Bloch sphere state |θ=0.2000, φ=2.1000⟩
# Fidelity: 0.9900332889
# Creating Bloch sphere state |θ=0.2000, φ=2.2000⟩
# Fidelity: 0.9900332889
# Creating Bloch sphere state |θ=0.2000, φ=2.3000⟩
# Fidelity: 0.9900332889
# Creating Bloch sphere state |θ=0.2000, φ=2.4000⟩
# Fidelity: 0.9900332889
# Creating Bloch sphere state |θ=0.2000, φ=2.5000⟩
# Fidelity: 0.9900332889
# Creating Bloch sphere state |θ=0.2000, φ=2.6000⟩
# Fidelity: 0.9900332889
# Creating Bloch sphere state |θ=0.2000, φ=2.7000⟩
# Fidelity: 0.9900332889
# Creating Bloch sphere state |θ=0.2000, φ=2.8000⟩
# Fidelity: 0.9900332889
# Creating Bloch sphere state |θ=0.2000, φ=2.9000⟩
# Fidelity: 0.9900332889
# Creating Bloch sphere state |θ=0.2000, φ=3.0000⟩
# Fidelity: 0.9900332889
# Creating Bloch sphere state |θ=0.2000, φ=3.1000⟩
# Fidelity: 0.9900332889
# Creating Bloch sphere state |θ=0.3000, φ=0.0000⟩
# Fidelity: 0.9776682446
# Creating Bloch sphere state |θ=0.3000, φ=0.1000⟩
# Fidelity: 0.9776682446
# Creating Bloch sphere state |θ=0.3000, φ=0.2000⟩
# Fidelity: 0.9776682446
# Creating Bloch sphere state |θ=0.3000, φ=0.3000⟩
# Fidelity: 0.9776682446
# Creating Bloch sphere state |θ=0.3000, φ=0.4000⟩
# Fidelity: 0.9776682446
# Creating Bloch sphere state |θ=0.3000, φ=0.5000⟩
# Fidelity: 0.9776682446
# Creating Bloch sphere state |θ=0.3000, φ=0.6000⟩
# Fidelity: 0.9776682446
# Creating Bloch sphere state |θ=0.3000, φ=0.7000⟩
# Fidelity: 0.9776682446
# Creating Bloch sphere state |θ=0.3000, φ=0.8000⟩
# Fidelity: 0.9776682446
# Creating Bloch sphere state |θ=0.3000, φ=0.9000⟩
# Fidelity: 0.9776682446
# Creating Bloch sphere state |θ=0.3000, φ=1.0000⟩
# Fidelity: 0.9776682446
# Creating Bloch sphere state |θ=0.3000, φ=1.1000⟩
# Fidelity: 0.9776682446
# Creating Bloch sphere state |θ=0.3000, φ=1.2000⟩
# Fidelity: 0.9776682446
# Creating Bloch sphere state |θ=0.3000, φ=1.3000⟩
# Fidelity: 0.9776682446
# Creating Bloch sphere state |θ=0.3000, φ=1.4000⟩
# Fidelity: 0.9776682446
# Creating Bloch sphere state |θ=0.3000, φ=1.5000⟩
# Fidelity: 0.9776682446
# Creating Bloch sphere state |θ=0.3000, φ=1.6000⟩
# Fidelity: 0.9776682446
# Creating Bloch sphere state |θ=0.3000, φ=1.7000⟩
# Fidelity: 0.9776682446
# Creating Bloch sphere state |θ=0.3000, φ=1.8000⟩
# Fidelity: 0.9776682446
# Creating Bloch sphere state |θ=0.3000, φ=1.9000⟩
# Fidelity: 0.9776682446
# Creating Bloch sphere state |θ=0.3000, φ=2.0000⟩
# Fidelity: 0.9776682446
# Creating Bloch sphere state |θ=0.3000, φ=2.1000⟩
# Fidelity: 0.9776682446
# Creating Bloch sphere state |θ=0.3000, φ=2.2000⟩
# Fidelity: 0.9776682446
# Creating Bloch sphere state |θ=0.3000, φ=2.3000⟩
# Fidelity: 0.9776682446
# Creating Bloch sphere state |θ=0.3000, φ=2.4000⟩
# Fidelity: 0.9776682446
# Creating Bloch sphere state |θ=0.3000, φ=2.5000⟩
# Fidelity: 0.9776682446
# Creating Bloch sphere state |θ=0.3000, φ=2.6000⟩
# Fidelity: 0.9776682446
# Creating Bloch sphere state |θ=0.3000, φ=2.7000⟩
# Fidelity: 0.9776682446
# Creating Bloch sphere state |θ=0.3000, φ=2.8000⟩
# Fidelity: 0.9776682446
# Creating Bloch sphere state |θ=0.3000, φ=2.9000⟩
# Fidelity: 0.9776682446
# Creating Bloch sphere state |θ=0.3000, φ=3.0000⟩
# Fidelity: 0.9776682446
# Creating Bloch sphere state |θ=0.3000, φ=3.1000⟩
# Fidelity: 0.9776682446
# Creating Bloch sphere state |θ=0.4000, φ=0.0000⟩
# Fidelity: 0.9605304970
# Creating Bloch sphere state |θ=0.4000, φ=0.1000⟩
# Fidelity: 0.9605304970
# Creating Bloch sphere state |θ=0.4000, φ=0.2000⟩
# Fidelity: 0.9605304970
# Creating Bloch sphere state |θ=0.4000, φ=0.3000⟩
# Fidelity: 0.9605304970
# Creating Bloch sphere state |θ=0.4000, φ=0.4000⟩
# Fidelity: 0.9605304970
# Creating Bloch sphere state |θ=0.4000, φ=0.5000⟩
# Fidelity: 0.9605304970
# Creating Bloch sphere state |θ=0.4000, φ=0.6000⟩
# Fidelity: 0.9605304970
# Creating Bloch sphere state |θ=0.4000, φ=0.7000⟩
# Fidelity: 0.9605304970
# Creating Bloch sphere state |θ=0.4000, φ=0.8000⟩
# Fidelity: 0.9605304970
# Creating Bloch sphere state |θ=0.4000, φ=0.9000⟩
# Fidelity: 0.9605304970
# Creating Bloch sphere state |θ=0.4000, φ=1.0000⟩
# Fidelity: 0.9605304970
# Creating Bloch sphere state |θ=0.4000, φ=1.1000⟩
# Fidelity: 0.9605304970
# Creating Bloch sphere state |θ=0.4000, φ=1.2000⟩
# Fidelity: 0.9605304970
# Creating Bloch sphere state |θ=0.4000, φ=1.3000⟩
# Fidelity: 0.9605304970
# Creating Bloch sphere state |θ=0.4000, φ=1.4000⟩
# Fidelity: 0.9605304970
# Creating Bloch sphere state |θ=0.4000, φ=1.5000⟩
# Fidelity: 0.9605304970
# Creating Bloch sphere state |θ=0.4000, φ=1.6000⟩
# Fidelity: 0.9605304970
# Creating Bloch sphere state |θ=0.4000, φ=1.7000⟩
# Fidelity: 0.9605304970
# Creating Bloch sphere state |θ=0.4000, φ=1.8000⟩
# Fidelity: 0.9605304970
# Creating Bloch sphere state |θ=0.4000, φ=1.9000⟩
# Fidelity: 0.9605304970
# Creating Bloch sphere state |θ=0.4000, φ=2.0000⟩
# Fidelity: 0.9605304970
# Creating Bloch sphere state |θ=0.4000, φ=2.1000⟩
# Fidelity: 0.9605304970
# Creating Bloch sphere state |θ=0.4000, φ=2.2000⟩
# Fidelity: 0.9605304970
# Creating Bloch sphere state |θ=0.4000, φ=2.3000⟩
# Fidelity: 0.9605304970
# Creating Bloch sphere state |θ=0.4000, φ=2.4000⟩
# Fidelity: 0.9605304970
# Creating Bloch sphere state |θ=0.4000, φ=2.5000⟩
# Fidelity: 0.9605304970
# Creating Bloch sphere state |θ=0.4000, φ=2.6000⟩
# Fidelity: 0.9605304970
# Creating Bloch sphere state |θ=0.4000, φ=2.7000⟩
# Fidelity: 0.9605304970
# Creating Bloch sphere state |θ=0.4000, φ=2.8000⟩
# Fidelity: 0.9605304970
# Creating Bloch sphere state |θ=0.4000, φ=2.9000⟩
# Fidelity: 0.9605304970
# Creating Bloch sphere state |θ=0.4000, φ=3.0000⟩
# Fidelity: 0.9605304970
# Creating Bloch sphere state |θ=0.4000, φ=3.1000⟩
# Fidelity: 0.9605304970
# Creating Bloch sphere state |θ=0.5000, φ=0.0000⟩
# Fidelity: 0.9387912809
# Creating Bloch sphere state |θ=0.5000, φ=0.1000⟩
# Fidelity: 0.9387912809
# Creating Bloch sphere state |θ=0.5000, φ=0.2000⟩
# Fidelity: 0.9387912809
# Creating Bloch sphere state |θ=0.5000, φ=0.3000⟩
# Fidelity: 0.9387912809
# Creating Bloch sphere state |θ=0.5000, φ=0.4000⟩
# Fidelity: 0.9387912809
# Creating Bloch sphere state |θ=0.5000, φ=0.5000⟩
# Fidelity: 0.9387912809
# Creating Bloch sphere state |θ=0.5000, φ=0.6000⟩
# Fidelity: 0.9387912809
# Creating Bloch sphere state |θ=0.5000, φ=0.7000⟩
# Fidelity: 0.9387912809
# Creating Bloch sphere state |θ=0.5000, φ=0.8000⟩
# Fidelity: 0.9387912809
# Creating Bloch sphere state |θ=0.5000, φ=0.9000⟩
# Fidelity: 0.9387912809
# Creating Bloch sphere state |θ=0.5000, φ=1.0000⟩
# Fidelity: 0.9387912809
# Creating Bloch sphere state |θ=0.5000, φ=1.1000⟩
# Fidelity: 0.9387912809
# Creating Bloch sphere state |θ=0.5000, φ=1.2000⟩
# Fidelity: 0.9387912809
# Creating Bloch sphere state |θ=0.5000, φ=1.3000⟩
# Fidelity: 0.9387912809
# Creating Bloch sphere state |θ=0.5000, φ=1.4000⟩
# Fidelity: 0.9387912809
# Creating Bloch sphere state |θ=0.5000, φ=1.5000⟩
# Fidelity: 0.9387912809
# Creating Bloch sphere state |θ=0.5000, φ=1.6000⟩
# Fidelity: 0.9387912809
# Creating Bloch sphere state |θ=0.5000, φ=1.7000⟩
# Fidelity: 0.9387912809
# Creating Bloch sphere state |θ=0.5000, φ=1.8000⟩
# Fidelity: 0.9387912809
# Creating Bloch sphere state |θ=0.5000, φ=1.9000⟩
# Fidelity: 0.9387912809
# Creating Bloch sphere state |θ=0.5000, φ=2.0000⟩
# Fidelity: 0.9387912809
# Creating Bloch sphere state |θ=0.5000, φ=2.1000⟩
# Fidelity: 0.9387912809
# Creating Bloch sphere state |θ=0.5000, φ=2.2000⟩
# Fidelity: 0.9387912809
# Creating Bloch sphere state |θ=0.5000, φ=2.3000⟩
# Fidelity: 0.9387912809
# Creating Bloch sphere state |θ=0.5000, φ=2.4000⟩
# Fidelity: 0.9387912809
# Creating Bloch sphere state |θ=0.5000, φ=2.5000⟩
# Fidelity: 0.9387912809
# Creating Bloch sphere state |θ=0.5000, φ=2.6000⟩
# Fidelity: 0.9387912809
# Creating Bloch sphere state |θ=0.5000, φ=2.7000⟩
# Fidelity: 0.9387912809
# Creating Bloch sphere state |θ=0.5000, φ=2.8000⟩
# Fidelity: 0.9387912809
# Creating Bloch sphere state |θ=0.5000, φ=2.9000⟩
# Fidelity: 0.9387912809
# Creating Bloch sphere state |θ=0.5000, φ=3.0000⟩
# Fidelity: 0.9387912809
# Creating Bloch sphere state |θ=0.5000, φ=3.1000⟩
# Fidelity: 0.9387912809
# Creating Bloch sphere state |θ=0.6000, φ=0.0000⟩
# Fidelity: 0.9126678075
# Creating Bloch sphere state |θ=0.6000, φ=0.1000⟩
# Fidelity: 0.9126678075
# Creating Bloch sphere state |θ=0.6000, φ=0.2000⟩
# Fidelity: 0.9126678075
# Creating Bloch sphere state |θ=0.6000, φ=0.3000⟩
# Fidelity: 0.9126678075
# Creating Bloch sphere state |θ=0.6000, φ=0.4000⟩
# Fidelity: 0.9126678075
# Creating Bloch sphere state |θ=0.6000, φ=0.5000⟩
# Fidelity: 0.9126678075
# Creating Bloch sphere state |θ=0.6000, φ=0.6000⟩
# Fidelity: 0.9126678075
# Creating Bloch sphere state |θ=0.6000, φ=0.7000⟩
# Fidelity: 0.9126678075
# Creating Bloch sphere state |θ=0.6000, φ=0.8000⟩
# Fidelity: 0.9126678075
# Creating Bloch sphere state |θ=0.6000, φ=0.9000⟩
# Fidelity: 0.9126678075
# Creating Bloch sphere state |θ=0.6000, φ=1.0000⟩
# Fidelity: 0.9126678075
# Creating Bloch sphere state |θ=0.6000, φ=1.1000⟩
# Fidelity: 0.9126678075
# Creating Bloch sphere state |θ=0.6000, φ=1.2000⟩
# Fidelity: 0.9126678075
# Creating Bloch sphere state |θ=0.6000, φ=1.3000⟩
# Fidelity: 0.9126678075
# Creating Bloch sphere state |θ=0.6000, φ=1.4000⟩
# Fidelity: 0.9126678075
# Creating Bloch sphere state |θ=0.6000, φ=1.5000⟩
# Fidelity: 0.9126678075
# Creating Bloch sphere state |θ=0.6000, φ=1.6000⟩
# Fidelity: 0.9126678075
# Creating Bloch sphere state |θ=0.6000, φ=1.7000⟩
# Fidelity: 0.9126678075
# Creating Bloch sphere state |θ=0.6000, φ=1.8000⟩
# Fidelity: 0.9126678075
# Creating Bloch sphere state |θ=0.6000, φ=1.9000⟩
# Fidelity: 0.9126678075
# Creating Bloch sphere state |θ=0.6000, φ=2.0000⟩
# Fidelity: 0.9126678075
# Creating Bloch sphere state |θ=0.6000, φ=2.1000⟩
# Fidelity: 0.9126678075
# Creating Bloch sphere state |θ=0.6000, φ=2.2000⟩
# Fidelity: 0.9126678075
# Creating Bloch sphere state |θ=0.6000, φ=2.3000⟩
# Fidelity: 0.9126678075
# Creating Bloch sphere state |θ=0.6000, φ=2.4000⟩
# Fidelity: 0.9126678075
# Creating Bloch sphere state |θ=0.6000, φ=2.5000⟩
# Fidelity: 0.9126678075
# Creating Bloch sphere state |θ=0.6000, φ=2.6000⟩
# Fidelity: 0.9126678075
# Creating Bloch sphere state |θ=0.6000, φ=2.7000⟩
# Fidelity: 0.9126678075
# Creating Bloch sphere state |θ=0.6000, φ=2.8000⟩
# Fidelity: 0.9126678075
# Creating Bloch sphere state |θ=0.6000, φ=2.9000⟩
# Fidelity: 0.9126678075
# Creating Bloch sphere state |θ=0.6000, φ=3.0000⟩
# Fidelity: 0.9126678075
# Creating Bloch sphere state |θ=0.6000, φ=3.1000⟩
# Fidelity: 0.9126678075
# Creating Bloch sphere state |θ=0.7000, φ=0.0000⟩
# Fidelity: 0.8824210936
# Creating Bloch sphere state |θ=0.7000, φ=0.1000⟩
# Fidelity: 0.8824210936
# Creating Bloch sphere state |θ=0.7000, φ=0.2000⟩
# Fidelity: 0.8824210936
# Creating Bloch sphere state |θ=0.7000, φ=0.3000⟩
# Fidelity: 0.8824210936
# Creating Bloch sphere state |θ=0.7000, φ=0.4000⟩
# Fidelity: 0.8824210936
# Creating Bloch sphere state |θ=0.7000, φ=0.5000⟩
# Fidelity: 0.8824210936
# Creating Bloch sphere state |θ=0.7000, φ=0.6000⟩
# Fidelity: 0.8824210936
# Creating Bloch sphere state |θ=0.7000, φ=0.7000⟩
# Fidelity: 0.8824210936
# Creating Bloch sphere state |θ=0.7000, φ=0.8000⟩
# Fidelity: 0.8824210936
# Creating Bloch sphere state |θ=0.7000, φ=0.9000⟩
# Fidelity: 0.8824210936
# Creating Bloch sphere state |θ=0.7000, φ=1.0000⟩
# Fidelity: 0.8824210936
# Creating Bloch sphere state |θ=0.7000, φ=1.1000⟩
# Fidelity: 0.8824210936
# Creating Bloch sphere state |θ=0.7000, φ=1.2000⟩
# Fidelity: 0.8824210936
# Creating Bloch sphere state |θ=0.7000, φ=1.3000⟩
# Fidelity: 0.8824210936
# Creating Bloch sphere state |θ=0.7000, φ=1.4000⟩
# Fidelity: 0.8824210936
# Creating Bloch sphere state |θ=0.7000, φ=1.5000⟩
# Fidelity: 0.8824210936
# Creating Bloch sphere state |θ=0.7000, φ=1.6000⟩
# Fidelity: 0.8824210936
# Creating Bloch sphere state |θ=0.7000, φ=1.7000⟩
# Fidelity: 0.8824210936
# Creating Bloch sphere state |θ=0.7000, φ=1.8000⟩
# Fidelity: 0.8824210936
# Creating Bloch sphere state |θ=0.7000, φ=1.9000⟩
# Fidelity: 0.8824210936
# Creating Bloch sphere state |θ=0.7000, φ=2.0000⟩
# Fidelity: 0.8824210936
# Creating Bloch sphere state |θ=0.7000, φ=2.1000⟩
# Fidelity: 0.8824210936
# Creating Bloch sphere state |θ=0.7000, φ=2.2000⟩
# Fidelity: 0.8824210936
# Creating Bloch sphere state |θ=0.7000, φ=2.3000⟩
# Fidelity: 0.8824210936
# Creating Bloch sphere state |θ=0.7000, φ=2.4000⟩
# Fidelity: 0.8824210936
# Creating Bloch sphere state |θ=0.7000, φ=2.5000⟩
# Fidelity: 0.8824210936
# Creating Bloch sphere state |θ=0.7000, φ=2.6000⟩
# Fidelity: 0.8824210936
# Creating Bloch sphere state |θ=0.7000, φ=2.7000⟩
# Fidelity: 0.8824210936
# Creating Bloch sphere state |θ=0.7000, φ=2.8000⟩
# Fidelity: 0.8824210936
# Creating Bloch sphere state |θ=0.7000, φ=2.9000⟩
# Fidelity: 0.8824210936
# Creating Bloch sphere state |θ=0.7000, φ=3.0000⟩
# Fidelity: 0.8824210936
# Creating Bloch sphere state |θ=0.7000, φ=3.1000⟩
# Fidelity: 0.8824210936
# Creating Bloch sphere state |θ=0.8000, φ=0.0000⟩
# Fidelity: 0.9999465873
# Creating Bloch sphere state |θ=0.8000, φ=0.1000⟩
# Fidelity: 0.9986795273
# Creating Bloch sphere state |θ=0.8000, φ=0.2000⟩
# Fidelity: 0.9948910037
# Creating Bloch sphere state |θ=0.8000, φ=0.3000⟩
# Fidelity: 0.9886188702
# Creating Bloch sphere state |θ=0.8000, φ=0.4000⟩
# Fidelity: 0.9799257959
# Creating Bloch sphere state |θ=0.8000, φ=0.5000⟩
# Fidelity: 0.9688986391
# Creating Bloch sphere state |θ=0.8000, φ=0.6000⟩
# Fidelity: 0.9556475795
# Creating Bloch sphere state |θ=0.8000, φ=0.7000⟩
# Fidelity: 0.9403050173
# Creating Bloch sphere state |θ=0.8000, φ=0.8000⟩
# Fidelity: 0.9999195410
# Creating Bloch sphere state |θ=0.8000, φ=0.9000⟩
# Fidelity: 0.9982829083
# Creating Bloch sphere state |θ=0.8000, φ=1.0000⟩
# Fidelity: 0.9941287750
# Creating Bloch sphere state |θ=0.8000, φ=1.1000⟩
# Fidelity: 0.9874986476
# Creating Bloch sphere state |θ=0.8000, φ=1.2000⟩
# Fidelity: 0.9784587724
# Creating Bloch sphere state |θ=0.8000, φ=1.3000⟩
# Fidelity: 0.9670994726
# Creating Bloch sphere state |θ=0.8000, φ=1.4000⟩
# Fidelity: 0.9535342467
# Creating Bloch sphere state |θ=0.8000, φ=1.5000⟩
# Fidelity: 0.9378986339
# Creating Bloch sphere state |θ=0.8000, φ=1.6000⟩
# Fidelity: 0.9998384434
# Creating Bloch sphere state |θ=0.8000, φ=1.7000⟩
# Fidelity: 0.9978325884
# Creating Bloch sphere state |θ=0.8000, φ=1.8000⟩
# Fidelity: 0.9933137322
# Creating Bloch sphere state |θ=0.8000, φ=1.9000⟩
# Fidelity: 0.9863270256
# Creating Bloch sphere state |θ=0.8000, φ=2.0000⟩
# Fidelity: 0.9769422776
# Creating Bloch sphere state |θ=0.8000, φ=2.1000⟩
# Fidelity: 0.9652532574
# Creating Bloch sphere state |θ=0.8000, φ=2.2000⟩
# Fidelity: 0.9513767578
# Creating Bloch sphere state |θ=0.8000, φ=2.3000⟩
# Fidelity: 0.9354514284
# Creating Bloch sphere state |θ=0.8000, φ=2.4000⟩
# Fidelity: 0.9997032716
# Creating Bloch sphere state |θ=0.8000, φ=2.5000⟩
# Fidelity: 0.9973286216
# Creating Bloch sphere state |θ=0.8000, φ=2.6000⟩
# Fidelity: 0.9924460057
# Creating Bloch sphere state |θ=0.8000, φ=2.7000⟩
# Fidelity: 0.9851042095
# Creating Bloch sphere state |θ=0.8000, φ=2.8000⟩
# Fidelity: 0.9753765898
# Creating Bloch sphere state |θ=0.8000, φ=2.9000⟩
# Fidelity: 0.9633603418
# Creating Bloch sphere state |θ=0.8000, φ=3.0000⟩
# Fidelity: 0.9491755278
# Creating Bloch sphere state |θ=0.8000, φ=3.1000⟩
# Fidelity: 0.9329638778
# Creating Bloch sphere state |θ=0.9000, φ=0.0000⟩
# Fidelity: 0.9967200858
# Creating Bloch sphere state |θ=0.9000, φ=0.1000⟩
# Fidelity: 0.9953365021
# Creating Bloch sphere state |θ=0.9000, φ=0.2000⟩
# Fidelity: 0.9911995713
# Creating Bloch sphere state |θ=0.9000, φ=0.3000⟩
# Fidelity: 0.9843506284
# Creating Bloch sphere state |θ=0.9000, φ=0.4000⟩
# Fidelity: 0.9748581056
# Creating Bloch sphere state |θ=0.9000, φ=0.5000⟩
# Fidelity: 0.9628168492
# Creating Bloch sphere state |θ=0.9000, φ=0.6000⟩
# Fidelity: 0.9483471713
# Creating Bloch sphere state |θ=0.9000, φ=0.7000⟩
# Fidelity: 0.9315936482
# Creating Bloch sphere state |θ=0.9000, φ=0.8000⟩
# Fidelity: 0.9966905520
# Creating Bloch sphere state |θ=0.9000, φ=0.9000⟩
# Fidelity: 0.9949034084
# Creating Bloch sphere state |θ=0.9000, φ=1.0000⟩
# Fidelity: 0.9903672449
# Creating Bloch sphere state |θ=0.9000, φ=1.1000⟩
# Fidelity: 0.9831273857
# Creating Bloch sphere state |θ=0.9000, φ=1.2000⟩
# Fidelity: 0.9732561688
# Creating Bloch sphere state |θ=0.9000, φ=1.3000⟩
# Fidelity: 0.9608522242
# Creating Bloch sphere state |θ=0.9000, φ=1.4000⟩
# Fidelity: 0.9460394881
# Creating Bloch sphere state |θ=0.9000, φ=1.5000⟩
# Fidelity: 0.9289659643
# Creating Bloch sphere state |θ=0.9000, φ=1.6000⟩
# Fidelity: 0.9966019966
# Creating Bloch sphere state |θ=0.9000, φ=1.7000⟩
# Fidelity: 0.9944116755
# Creating Bloch sphere state |θ=0.9000, φ=1.8000⟩
# Fidelity: 0.9894772479
# Creating Bloch sphere state |θ=0.9000, φ=1.9000⟩
# Fidelity: 0.9818480170
# Creating Bloch sphere state |θ=0.9000, φ=2.0000⟩
# Fidelity: 0.9716002115
# Creating Bloch sphere state |θ=0.9000, φ=2.1000⟩
# Fidelity: 0.9588362242
# Creating Bloch sphere state |θ=0.9000, φ=2.2000⟩
# Fidelity: 0.9436835885
# Creating Bloch sphere state |θ=0.9000, φ=2.3000⟩
# Fidelity: 0.9262937046
# Creating Bloch sphere state |θ=0.9000, φ=2.4000⟩
# Fidelity: 0.9964543936
# Creating Bloch sphere state |θ=0.9000, φ=2.5000⟩
# Fidelity: 0.9938613616
# Creating Bloch sphere state |θ=0.9000, φ=2.6000⟩
# Fidelity: 0.9885297216
# Creating Bloch sphere state |θ=0.9000, φ=2.7000⟩
# Fidelity: 0.9805127457
# Creating Bloch sphere state |θ=0.9000, φ=2.8000⟩
# Fidelity: 0.9698905368
# Creating Bloch sphere state |θ=0.9000, φ=2.9000⟩
# Fidelity: 0.9567692285
# Creating Bloch sphere state |θ=0.9000, φ=3.0000⟩
# Fidelity: 0.9412799245
# Creating Bloch sphere state |θ=0.9000, φ=3.1000⟩
# Fidelity: 0.9235773890
# Creating Bloch sphere state |θ=1.0000, φ=0.0000⟩
# Fidelity: 0.9885305208
# Creating Bloch sphere state |θ=1.0000, φ=0.1000⟩
# Fidelity: 0.9870442377
# Creating Bloch sphere state |θ=1.0000, φ=0.2000⟩
# Fidelity: 0.9826002347
# Creating Bloch sphere state |θ=1.0000, φ=0.3000⟩
# Fidelity: 0.9752429146
# Creating Bloch sphere state |θ=1.0000, φ=0.4000⟩
# Fidelity: 0.9650457895
# Creating Bloch sphere state |θ=1.0000, φ=0.5000⟩
# Fidelity: 0.9521107457
# Creating Bloch sphere state |θ=1.0000, φ=0.6000⟩
# Fidelity: 0.9365670258
# Creating Bloch sphere state |θ=1.0000, φ=0.7000⟩
# Fidelity: 0.9185699375
# Creating Bloch sphere state |θ=1.0000, φ=0.8000⟩
# Fidelity: 0.9884987947
# Creating Bloch sphere state |θ=1.0000, φ=0.9000⟩
# Fidelity: 0.9865789965
# Creating Bloch sphere state |θ=1.0000, φ=1.0000⟩
# Fidelity: 0.9817061269
# Creating Bloch sphere state |θ=1.0000, φ=1.1000⟩
# Fidelity: 0.9739288739
# Creating Bloch sphere state |θ=1.0000, φ=1.2000⟩
# Fidelity: 0.9633249454
# Creating Bloch sphere state |θ=1.0000, φ=1.3000⟩
# Fidelity: 0.9500002921
# Creating Bloch sphere state |θ=1.0000, φ=1.4000⟩
# Fidelity: 0.9340880497
# Creating Bloch sphere state |θ=1.0000, φ=1.5000⟩
# Fidelity: 0.9157472081
# Creating Bloch sphere state |θ=1.0000, φ=1.6000⟩
# Fidelity: 0.9884036663
# Creating Bloch sphere state |θ=1.0000, φ=1.7000⟩
# Fidelity: 0.9860507640
# Creating Bloch sphere state |θ=1.0000, φ=1.8000⟩
# Fidelity: 0.9807500682
# Creating Bloch sphere state |θ=1.0000, φ=1.9000⟩
# Fidelity: 0.9725545417
# Creating Bloch sphere state |θ=1.0000, φ=2.0000⟩
# Fidelity: 0.9615460715
# Creating Bloch sphere state |θ=1.0000, φ=2.1000⟩
# Fidelity: 0.9478346505
# Creating Bloch sphere state |θ=1.0000, φ=2.2000⟩
# Fidelity: 0.9315572788
# Creating Bloch sphere state |θ=1.0000, φ=2.3000⟩
# Fidelity: 0.9128765945
# Creating Bloch sphere state |θ=1.0000, φ=2.4000⟩
# Fidelity: 0.9882451068
# Creating Bloch sphere state |θ=1.0000, φ=2.5000⟩
# Fidelity: 0.9854596016
# Creating Bloch sphere state |θ=1.0000, φ=2.6000⟩
# Fidelity: 0.9797322095
# Creating Bloch sphere state |θ=1.0000, φ=2.7000⟩
# Fidelity: 0.9711201568
# Creating Bloch sphere state |θ=1.0000, φ=2.8000⟩
# Fidelity: 0.9597094922
# Creating Bloch sphere state |θ=1.0000, φ=2.9000⟩
# Fidelity: 0.9456142274
# Creating Bloch sphere state |θ=1.0000, φ=3.0000⟩
# Fidelity: 0.9289751976
# Creating Bloch sphere state |θ=1.0000, φ=3.1000⟩
# Fidelity: 0.9099586543
# Creating Bloch sphere state |θ=1.1000, φ=0.0000⟩
# Fidelity: 0.9754597199
# Creating Bloch sphere state |θ=1.1000, φ=0.1000⟩
# Fidelity: 0.9738855878
# Creating Bloch sphere state |θ=1.1000, φ=0.2000⟩
# Fidelity: 0.9691789155
# Creating Bloch sphere state |θ=1.1000, φ=0.3000⟩
# Fidelity: 0.9613867302
# Creating Bloch sphere state |θ=1.1000, φ=0.4000⟩
# Fidelity: 0.9505868891
# Creating Bloch sphere state |θ=1.1000, φ=0.5000⟩
# Fidelity: 0.9368873006
# Creating Bloch sphere state |θ=1.1000, φ=0.6000⟩
# Fidelity: 0.9204248463
# Creating Bloch sphere state |θ=1.1000, φ=0.7000⟩
# Fidelity: 0.9013640138
# Creating Bloch sphere state |θ=1.1000, φ=0.8000⟩
# Fidelity: 0.9754261182
# Creating Bloch sphere state |θ=1.1000, φ=0.9000⟩
# Fidelity: 0.9733928476
# Creating Bloch sphere state |θ=1.1000, φ=1.0000⟩
# Fidelity: 0.9682319599
# Creating Bloch sphere state |θ=1.1000, φ=1.1000⟩
# Fidelity: 0.9599950210
# Creating Bloch sphere state |θ=1.1000, φ=1.2000⟩
# Fidelity: 0.9487643317
# Creating Bloch sphere state |θ=1.1000, φ=1.3000⟩
# Fidelity: 0.9346521053
# Creating Bloch sphere state |θ=1.1000, φ=1.4000⟩
# Fidelity: 0.9177993465
# Creating Bloch sphere state |θ=1.1000, φ=1.5000⟩
# Fidelity: 0.8983744425
# Creating Bloch sphere state |θ=1.1000, φ=1.6000⟩
# Fidelity: 0.9753253674
# Creating Bloch sphere state |θ=1.1000, φ=1.7000⟩
# Fidelity: 0.9728333934
# Creating Bloch sphere state |θ=1.1000, φ=1.8000⟩
# Fidelity: 0.9672193922
# Creating Bloch sphere state |θ=1.1000, φ=1.9000⟩
# Fidelity: 0.9585394571
# Creating Bloch sphere state |θ=1.1000, φ=2.0000⟩
# Fidelity: 0.9468803151
# Creating Bloch sphere state |θ=1.1000, φ=2.1000⟩
# Fidelity: 0.9323584605
# Creating Bloch sphere state |θ=1.1000, φ=2.2000⟩
# Fidelity: 0.9151189909
# Creating Bloch sphere state |θ=1.1000, φ=2.3000⟩
# Fidelity: 0.8953341574
# Creating Bloch sphere state |θ=1.1000, φ=2.4000⟩
# Fidelity: 0.9751574356
# Creating Bloch sphere state |θ=1.1000, φ=2.5000⟩
# Fidelity: 0.9722072890
# Creating Bloch sphere state |θ=1.1000, φ=2.6000⟩
# Fidelity: 0.9661413711
# Creating Bloch sphere state |θ=1.1000, φ=2.7000⟩
# Fidelity: 0.9570202904
# Creating Bloch sphere state |θ=1.1000, φ=2.8000⟩
# Fidelity: 0.9449351818
# Creating Bloch sphere state |θ=1.1000, φ=2.9000⟩
# Fidelity: 0.9300067957
# Creating Bloch sphere state |θ=1.1000, φ=3.0000⟩
# Fidelity: 0.9123842916
# Creating Bloch sphere state |θ=1.1000, φ=3.1000⟩
# Fidelity: 0.8922437477
# Creating Bloch sphere state |θ=1.2000, φ=0.0000⟩
# Fidelity: 0.9576382820
# Creating Bloch sphere state |θ=1.2000, φ=0.1000⟩
# Fidelity: 0.9559920292
# Creating Bloch sphere state |θ=1.2000, φ=0.2000⟩
# Fidelity: 0.9510697151
# Creating Bloch sphere state |θ=1.2000, φ=0.3000⟩
# Fidelity: 0.9429205216
# Creating Bloch sphere state |θ=1.2000, φ=0.4000⟩
# Fidelity: 0.9316258729
# Creating Bloch sphere state |θ=1.2000, φ=0.5000⟩
# Fidelity: 0.9172986214
# Creating Bloch sphere state |θ=1.2000, φ=0.6000⟩
# Fidelity: 0.9000819202
# Creating Bloch sphere state |θ=1.2000, φ=0.7000⟩
# Fidelity: 0.8801477929
# Creating Bloch sphere state |θ=1.2000, φ=0.8000⟩
# Fidelity: 0.9576031406
# Creating Bloch sphere state |θ=1.2000, φ=0.9000⟩
# Fidelity: 0.9554767132
# Creating Bloch sphere state |θ=1.2000, φ=1.0000⟩
# Fidelity: 0.9500793733
# Creating Bloch sphere state |θ=1.2000, φ=1.1000⟩
# Fidelity: 0.9414650492
# Creating Bloch sphere state |θ=1.2000, φ=1.2000⟩
# Fidelity: 0.9297198125
# Creating Bloch sphere state |θ=1.2000, φ=1.3000⟩
# Fidelity: 0.9149610177
# Creating Bloch sphere state |θ=1.2000, φ=1.4000⟩
# Fidelity: 0.8973361297
# Creating Bloch sphere state |θ=1.2000, φ=1.5000⟩
# Fidelity: 0.8770212506
# Creating Bloch sphere state |θ=1.2000, φ=1.6000⟩
# Fidelity: 0.9574977740
# Creating Bloch sphere state |θ=1.2000, φ=1.7000⟩
# Fidelity: 0.9548916272
# Creating Bloch sphere state |θ=1.2000, φ=1.8000⟩
# Fidelity: 0.9490204139
# Creating Bloch sphere state |θ=1.2000, φ=1.9000⟩
# Fidelity: 0.9399427972
# Creating Bloch sphere state |θ=1.2000, φ=2.0000⟩
# Fidelity: 0.9277494778
# Creating Bloch sphere state |θ=1.2000, φ=2.1000⟩
# Fidelity: 0.9125622871
# Creating Bloch sphere state |θ=1.2000, φ=2.2000⟩
# Fidelity: 0.8945329707
# Creating Bloch sphere state |θ=1.2000, φ=2.3000⟩
# Fidelity: 0.8738416715
# Creating Bloch sphere state |θ=1.2000, φ=2.4000⟩
# Fidelity: 0.9573221478
# Creating Bloch sphere state |θ=1.2000, φ=2.5000⟩
# Fidelity: 0.9542368367
# Creating Bloch sphere state |θ=1.2000, φ=2.6000⟩
# Fidelity: 0.9478930015
# Creating Bloch sphere state |θ=1.2000, φ=2.7000⟩
# Fidelity: 0.9383540276
# Creating Bloch sphere state |θ=1.2000, φ=2.8000⟩
# Fidelity: 0.9257152254
# Creating Bloch sphere state |θ=1.2000, φ=2.9000⟩
# Fidelity: 0.9101028775
# Creating Bloch sphere state |θ=1.2000, φ=3.0000⟩
# Fidelity: 0.8916729774
# Creating Bloch sphere state |θ=1.2000, φ=3.1000⟩
# Fidelity: 0.8706096706
# Creating Bloch sphere state |θ=1.3000, φ=0.0000⟩
# Fidelity: 0.9352442731
# Creating Bloch sphere state |θ=1.3000, φ=0.1000⟩
# Fidelity: 0.9335423485
# Creating Bloch sphere state |θ=1.3000, φ=0.2000⟩
# Fidelity: 0.9284535746
# Creating Bloch sphere state |θ=1.3000, φ=0.3000⟩
# Fidelity: 0.9200287970
# Creating Bloch sphere state |θ=1.3000, φ=0.4000⟩
# Fidelity: 0.9083521931
# Creating Bloch sphere state |θ=1.3000, φ=0.5000⟩
# Fidelity: 0.8935404318
# Creating Bloch sphere state |θ=1.3000, φ=0.6000⟩
# Fidelity: 0.8757415073
# Creating Bloch sphere state |θ=1.3000, φ=0.7000⟩
# Fidelity: 0.8551332605
# Creating Bloch sphere state |θ=1.3000, φ=0.8000⟩
# Fidelity: 0.9352079430
# Creating Bloch sphere state |θ=1.3000, φ=0.9000⟩
# Fidelity: 0.9330096055
# Creating Bloch sphere state |θ=1.3000, φ=1.0000⟩
# Fidelity: 0.9274297418
# Creating Bloch sphere state |θ=1.3000, φ=1.1000⟩
# Fidelity: 0.9185241041
# Creating Bloch sphere state |θ=1.3000, φ=1.2000⟩
# Fidelity: 0.9063816745
# Creating Bloch sphere state |θ=1.3000, φ=1.3000⟩
# Fidelity: 0.8911237762
# Creating Bloch sphere state |θ=1.3000, φ=1.4000⟩
# Fidelity: 0.8729028610
# Creating Bloch sphere state |θ=1.3000, φ=1.5000⟩
# Fidelity: 0.8519009864
# Creating Bloch sphere state |θ=1.3000, φ=1.6000⟩
# Fidelity: 0.9350990135
# Creating Bloch sphere state |θ=1.3000, φ=1.7000⟩
# Fidelity: 0.9324047338
# Creating Bloch sphere state |θ=1.3000, φ=1.8000⟩
# Fidelity: 0.9263349715
# Creating Bloch sphere state |θ=1.3000, φ=1.9000⟩
# Fidelity: 0.9169503738
# Creating Bloch sphere state |θ=1.3000, φ=2.0000⟩
# Fidelity: 0.9043447085
# Creating Bloch sphere state |θ=1.3000, φ=2.1000⟩
# Fidelity: 0.8886439272
# Creating Bloch sphere state |θ=1.3000, φ=2.2000⟩
# Fidelity: 0.8700049070
# Creating Bloch sphere state |θ=1.3000, φ=2.3000⟩
# Fidelity: 0.8486138826
# Creating Bloch sphere state |θ=1.3000, φ=2.4000⟩
# Fidelity: 0.9349174476
# Creating Bloch sphere state |θ=1.3000, φ=2.5000⟩
# Fidelity: 0.9317277995
# Creating Bloch sphere state |θ=1.3000, φ=2.6000⟩
# Fidelity: 0.9251694325
# Creating Bloch sphere state |θ=1.3000, φ=2.7000⟩
# Fidelity: 0.9153078758
# Creating Bloch sphere state |θ=1.3000, φ=2.8000⟩
# Fidelity: 0.9022416626
# Creating Bloch sphere state |θ=1.3000, φ=2.9000⟩
# Fidelity: 0.8861013464
# Creating Bloch sphere state |θ=1.3000, φ=3.0000⟩
# Fidelity: 0.8670481958
# Creating Bloch sphere state |θ=1.3000, φ=3.1000⟩
# Fidelity: 0.8452725836
# Creating Bloch sphere state |θ=1.4000, φ=0.0000⟩
# Fidelity: 0.9085014468
# Creating Bloch sphere state |θ=1.4000, φ=0.1000⟩
# Fidelity: 0.9067608553
# Creating Bloch sphere state |θ=1.4000, φ=0.2000⟩
# Fidelity: 0.9015564671
# Creating Bloch sphere state |θ=1.4000, φ=0.3000⟩
# Fidelity: 0.8929402829
# Creating Bloch sphere state |θ=1.4000, φ=0.4000⟩
# Fidelity: 0.8809983926
# Creating Bloch sphere state |θ=1.4000, φ=0.5000⟩
# Fidelity: 0.8658501157
# Creating Bloch sphere state |θ=1.4000, φ=0.6000⟩
# Fidelity: 0.8476468088
# Creating Bloch sphere state |θ=1.4000, φ=0.7000⟩
# Fidelity: 0.8265703533
# Creating Bloch sphere state |θ=1.4000, φ=0.8000⟩
# Fidelity: 0.9084642909
# Creating Bloch sphere state |θ=1.4000, φ=0.9000⟩
# Fidelity: 0.9062160083
# Creating Bloch sphere state |θ=1.4000, φ=1.0000⟩
# Fidelity: 0.9005093730
# Creating Bloch sphere state |θ=1.4000, φ=1.1000⟩
# Fidelity: 0.8914014038
# Creating Bloch sphere state |θ=1.4000, φ=1.2000⟩
# Fidelity: 0.8789831045
# Creating Bloch sphere state |θ=1.4000, φ=1.3000⟩
# Fidelity: 0.8633785546
# Creating Bloch sphere state |θ=1.4000, φ=1.4000⟩
# Fidelity: 0.8447436697
# Creating Bloch sphere state |θ=1.4000, φ=1.5000⟩
# Fidelity: 0.8232646433
# Creating Bloch sphere state |θ=1.4000, φ=1.6000⟩
# Fidelity: 0.9083528870
# Creating Bloch sphere state |θ=1.4000, φ=1.7000⟩
# Fidelity: 0.9055973946
# Creating Bloch sphere state |θ=1.4000, φ=1.8000⟩
# Fidelity: 0.8993897305
# Creating Bloch sphere state |θ=1.4000, φ=1.9000⟩
# Fidelity: 0.8897919196
# Creating Bloch sphere state |θ=1.4000, φ=2.0000⟩
# Fidelity: 0.8768998601
# Creating Bloch sphere state |θ=1.4000, φ=2.1000⟩
# Fidelity: 0.8608423651
# Creating Bloch sphere state |θ=1.4000, φ=2.2000⟩
# Fidelity: 0.8417798759
# Creating Bloch sphere state |θ=1.4000, φ=2.3000⟩
# Fidelity: 0.8199028586
# Creating Bloch sphere state |θ=1.4000, φ=2.4000⟩
# Fidelity: 0.9081671955
# Creating Bloch sphere state |θ=1.4000, φ=2.5000⟩
# Fidelity: 0.9049050802
# Creating Bloch sphere state |θ=1.4000, φ=2.6000⟩
# Fidelity: 0.8981977105
# Creating Bloch sphere state |θ=1.4000, φ=2.7000⟩
# Fidelity: 0.8881121043
# Creating Bloch sphere state |θ=1.4000, φ=2.8000⟩
# Fidelity: 0.8747490335
# Creating Bloch sphere state |θ=1.4000, φ=2.9000⟩
# Fidelity: 0.8582420176
# Creating Bloch sphere state |θ=1.4000, φ=3.0000⟩
# Fidelity: 0.8387559893
# Creating Bloch sphere state |θ=1.4000, φ=3.1000⟩
# Fidelity: 0.8164856464
# Creating Bloch sphere state |θ=1.5000, φ=0.0000⟩
# Fidelity: 0.8776770085
# Creating Bloch sphere state |θ=1.5000, φ=0.1000⟩
# Fidelity: 0.8759151416
# Creating Bloch sphere state |θ=1.5000, φ=0.2000⟩
# Fidelity: 0.8706471396
# Creating Bloch sphere state |θ=1.5000, φ=0.3000⟩
# Fidelity: 0.8619256388
# Creating Bloch sphere state |θ=1.5000, φ=0.4000⟩
# Fidelity: 0.8498377816
# Creating Bloch sphere state |θ=1.5000, φ=0.5000⟩
# Fidelity: 0.8345043457
# Creating Bloch sphere state |θ=1.5000, φ=0.6000⟩
# Fidelity: 0.8160785378
# Creating Bloch sphere state |θ=1.5000, φ=0.7000⟩
# Fidelity: 0.7947444626
# Creating Bloch sphere state |θ=1.5000, φ=0.8000⟩
# Fidelity: 0.8776393981
# Creating Bloch sphere state |θ=1.5000, φ=0.9000⟩
# Fidelity: 0.8753636345
# Creating Bloch sphere state |θ=1.5000, φ=1.0000⟩
# Fidelity: 0.8695872464
# Creating Bloch sphere state |θ=1.5000, φ=1.1000⟩
# Fidelity: 0.8603679495
# Creating Bloch sphere state |θ=1.5000, φ=1.2000⟩
# Fidelity: 0.8477978600
# Creating Bloch sphere state |θ=1.5000, φ=1.3000⟩
# Fidelity: 0.8320025740
# Creating Bloch sphere state |θ=1.5000, φ=1.4000⟩
# Fidelity: 0.8131399129
# Creating Bloch sphere state |θ=1.5000, φ=1.5000⟩
# Fidelity: 0.7913983461
# Creating Bloch sphere state |θ=1.5000, φ=1.6000⟩
# Fidelity: 0.8775266328
# Creating Bloch sphere state |θ=1.5000, φ=1.7000⟩
# Fidelity: 0.8747374598
# Creating Bloch sphere state |θ=1.5000, φ=1.8000⟩
# Fidelity: 0.8684539187
# Creating Bloch sphere state |θ=1.5000, φ=1.9000⟩
# Fidelity: 0.8587387927
# Creating Bloch sphere state |θ=1.5000, φ=2.0000⟩
# Fidelity: 0.8456891522
# Creating Bloch sphere state |θ=1.5000, φ=2.1000⟩
# Fidelity: 0.8294353848
# Creating Bloch sphere state |θ=1.5000, φ=2.2000⟩
# Fidelity: 0.8101398928
# Creating Bloch sphere state |θ=1.5000, φ=2.3000⟩
# Fidelity: 0.7879954703
# Creating Bloch sphere state |θ=1.5000, φ=2.4000⟩
# Fidelity: 0.8773386710
# Creating Bloch sphere state |θ=1.5000, φ=2.5000⟩
# Fidelity: 0.8740366825
# Creating Bloch sphere state |θ=1.5000, φ=2.6000⟩
# Fidelity: 0.8672473280
# Creating Bloch sphere state |θ=1.5000, φ=2.7000⟩
# Fidelity: 0.8570384443
# Creating Bloch sphere state |θ=1.5000, φ=2.8000⟩
# Fidelity: 0.8435120353
# Creating Bloch sphere state |θ=1.5000, φ=2.9000⟩
# Fidelity: 0.8268032524
# Creating Bloch sphere state |θ=1.5000, φ=3.0000⟩
# Fidelity: 0.8070790443
# Creating Bloch sphere state |θ=1.5000, φ=3.1000⟩
# Fidelity: 0.7845364886
# Creating Bloch sphere state |θ=1.6000, φ=0.0000⟩
# Fidelity: 0.9997868015
# Creating Bloch sphere state |θ=1.6000, φ=0.1000⟩
# Fidelity: 0.9972899493
# Creating Bloch sphere state |θ=1.6000, φ=0.2000⟩
# Fidelity: 0.9898243402
# Creating Bloch sphere state |θ=1.6000, φ=0.3000⟩
# Fidelity: 0.9774645683
# Creating Bloch sphere state |θ=1.6000, φ=0.4000⟩
# Fidelity: 0.9603341282
# Creating Bloch sphere state |θ=1.6000, φ=0.5000⟩
# Fidelity: 0.9386041817
# Creating Bloch sphere state |θ=1.6000, φ=0.6000⟩
# Fidelity: 0.9124918472
# Creating Bloch sphere state |θ=1.6000, φ=0.7000⟩
# Fidelity: 0.8822580305
# Creating Bloch sphere state |θ=1.6000, φ=0.8000⟩
# Fidelity: 0.9997335044
# Creating Bloch sphere state |θ=1.6000, φ=0.9000⟩
# Fidelity: 0.9965083795
# Creating Bloch sphere state |θ=1.6000, φ=1.0000⟩
# Fidelity: 0.9883223068
# Creating Bloch sphere state |θ=1.6000, φ=1.1000⟩
# Fidelity: 0.9752570790
# Creating Bloch sphere state |θ=1.6000, φ=1.2000⟩
# Fidelity: 0.9574432395
# Creating Bloch sphere state |θ=1.6000, φ=1.3000⟩
# Fidelity: 0.9350587782
# Creating Bloch sphere state |θ=1.6000, φ=1.4000⟩
# Fidelity: 0.9083273533
# Creating Bloch sphere state |θ=1.6000, φ=1.5000⟩
# Fidelity: 0.8775160565
# Creating Bloch sphere state |θ=1.6000, φ=1.6000⟩
# Fidelity: 0.9995736939
# Creating Bloch sphere state |θ=1.6000, φ=1.7000⟩
# Fidelity: 0.9956209838
# Creating Bloch sphere state |θ=1.6000, φ=1.8000⟩
# Fidelity: 0.9867161926
# Creating Bloch sphere state |θ=1.6000, φ=1.9000⟩
# Fidelity: 0.9729482941
# Creating Bloch sphere state |θ=1.6000, φ=2.0000⟩
# Fidelity: 0.9544548526
# Creating Bloch sphere state |θ=1.6000, φ=2.1000⟩
# Fidelity: 0.9314206484
# Creating Bloch sphere state |θ=1.6000, φ=2.2000⟩
# Fidelity: 0.9040758317
# Creating Bloch sphere state |θ=1.6000, φ=2.3000⟩
# Fidelity: 0.8726936229
# Creating Bloch sphere state |θ=1.6000, φ=2.4000⟩
# Fidelity: 0.9993073347
# Creating Bloch sphere state |θ=1.6000, φ=2.5000⟩
# Fidelity: 0.9946278823
# Creating Bloch sphere state |θ=1.6000, φ=2.6000⟩
# Fidelity: 0.9850062714
# Creating Bloch sphere state |θ=1.6000, φ=2.7000⟩
# Fidelity: 0.9705386382
# Creating Bloch sphere state |θ=1.6000, φ=2.8000⟩
# Fidelity: 0.9513695383
# Creating Bloch sphere state |θ=1.6000, φ=2.9000⟩
# Fidelity: 0.9276905031
# Creating Bloch sphere state |θ=1.6000, φ=3.0000⟩
# Fidelity: 0.8997381257
# Creating Bloch sphere state |θ=1.6000, φ=3.1000⟩
# Fidelity: 0.8677916970
# Creating Bloch sphere state |θ=1.7000, φ=0.0000⟩
# Fidelity: 0.9958324052
# Creating Bloch sphere state |θ=1.7000, φ=0.1000⟩
# Fidelity: 0.9933553085
# Creating Bloch sphere state |θ=1.7000, φ=0.2000⟩
# Fidelity: 0.9859487686
# Creating Bloch sphere state |θ=1.7000, φ=0.3000⟩
# Fidelity: 0.9736867892
# Creating Bloch sphere state |θ=1.7000, φ=0.4000⟩
# Fidelity: 0.9566918880
# Creating Bloch sphere state |θ=1.7000, φ=0.5000⟩
# Fidelity: 0.9351338724
# Creating Bloch sphere state |θ=1.7000, φ=0.6000⟩
# Fidelity: 0.9092281431
# Creating Bloch sphere state |θ=1.7000, φ=0.7000⟩
# Fidelity: 0.8792335413
# Creating Bloch sphere state |θ=1.7000, φ=0.8000⟩
# Fidelity: 0.9957795289
# Creating Bloch sphere state |θ=1.7000, φ=0.9000⟩
# Fidelity: 0.9925799217
# Creating Bloch sphere state |θ=1.7000, φ=1.0000⟩
# Fidelity: 0.9844586186
# Creating Bloch sphere state |θ=1.7000, φ=1.1000⟩
# Fidelity: 0.9714967650
# Creating Bloch sphere state |θ=1.7000, φ=1.2000⟩
# Fidelity: 0.9538238715
# Creating Bloch sphere state |θ=1.7000, φ=1.3000⟩
# Fidelity: 0.9316165199
# Creating Bloch sphere state |θ=1.7000, φ=1.4000⟩
# Fidelity: 0.9050965985
# Creating Bloch sphere state |θ=1.7000, φ=1.5000⟩
# Fidelity: 0.8745290857
# Creating Bloch sphere state |θ=1.7000, φ=1.6000⟩
# Fidelity: 0.9956209838
# Creating Bloch sphere state |θ=1.7000, φ=1.7000⟩
# Fidelity: 0.9916995481
# Creating Bloch sphere state |θ=1.7000, φ=1.8000⟩
# Fidelity: 0.9828652131
# Creating Bloch sphere state |θ=1.7000, φ=1.9000⟩
# Fidelity: 0.9692062485
# Creating Bloch sphere state |θ=1.7000, φ=2.0000⟩
# Fidelity: 0.9508591302
# Creating Bloch sphere state |θ=1.7000, φ=2.1000⟩
# Fidelity: 0.9280071765
# Creating Bloch sphere state |θ=1.7000, φ=2.2000⟩
# Fidelity: 0.9008787165
# Creating Bloch sphere state |θ=1.7000, φ=2.3000⟩
# Fidelity: 0.8697448089
# Creating Bloch sphere state |θ=1.7000, φ=2.4000⟩
# Fidelity: 0.9953567311
# Creating Bloch sphere state |θ=1.7000, φ=2.5000⟩
# Fidelity: 0.9907143033
# Creating Bloch sphere state |θ=1.7000, φ=2.6000⟩
# Fidelity: 0.9811688202
# Creating Bloch sphere state |θ=1.7000, φ=2.7000⟩
# Fidelity: 0.9668156573
# Creating Bloch sphere state |θ=1.7000, φ=2.8000⟩
# Fidelity: 0.9477982265
# Creating Bloch sphere state |θ=1.7000, φ=2.9000⟩
# Fidelity: 0.9243065438
# Creating Bloch sphere state |θ=1.7000, φ=3.0000⟩
# Fidelity: 0.8965753302
# Creating Bloch sphere state |θ=1.7000, φ=3.1000⟩
# Fidelity: 0.8648816670
# Creating Bloch sphere state |θ=1.8000, φ=0.0000⟩
# Fidelity: 0.9869238154
# Creating Bloch sphere state |θ=1.8000, φ=0.1000⟩
# Fidelity: 0.9844912245
# Creating Bloch sphere state |θ=1.8000, φ=0.2000⟩
# Fidelity: 0.9772177575
# Creating Bloch sphere state |θ=1.8000, φ=0.3000⟩
# Fidelity: 0.9651760883
# Creating Bloch sphere state |θ=1.8000, φ=0.4000⟩
# Fidelity: 0.9484865335
# Creating Bloch sphere state |θ=1.8000, φ=0.5000⟩
# Fidelity: 0.9273158494
# Creating Bloch sphere state |θ=1.8000, φ=0.6000⟩
# Fidelity: 0.9018755666
# Creating Bloch sphere state |θ=1.8000, φ=0.7000⟩
# Fidelity: 0.8724198760
# Creating Bloch sphere state |θ=1.8000, φ=0.8000⟩
# Fidelity: 0.9868718881
# Creating Bloch sphere state |θ=1.8000, φ=0.9000⟩
# Fidelity: 0.9837297680
# Creating Bloch sphere state |θ=1.8000, φ=1.0000⟩
# Fidelity: 0.9757543799
# Creating Bloch sphere state |θ=1.8000, φ=1.1000⟩
# Fidelity: 0.9630254111
# Creating Bloch sphere state |θ=1.8000, φ=1.2000⟩
# Fidelity: 0.9456700454
# Creating Bloch sphere state |θ=1.8000, φ=1.3000⟩
# Fidelity: 0.9238616919
# Creating Bloch sphere state |θ=1.8000, φ=1.4000⟩
# Fidelity: 0.8978182522
# Creating Bloch sphere state |θ=1.8000, φ=1.5000⟩
# Fidelity: 0.8677999441
# Creating Bloch sphere state |θ=1.8000, φ=1.6000⟩
# Fidelity: 0.9867161926
# Creating Bloch sphere state |θ=1.8000, φ=1.7000⟩
# Fidelity: 0.9828652131
# Creating Bloch sphere state |θ=1.8000, φ=1.8000⟩
# Fidelity: 0.9741896041
# Creating Bloch sphere state |θ=1.8000, φ=1.9000⟩
# Fidelity: 0.9607760492
# Creating Bloch sphere state |θ=1.8000, φ=2.0000⟩
# Fidelity: 0.9427585724
# Creating Bloch sphere state |θ=1.8000, φ=2.1000⟩
# Fidelity: 0.9203171983
# Creating Bloch sphere state |θ=1.8000, φ=2.2000⟩
# Fidelity: 0.8936761537
# Creating Bloch sphere state |θ=1.8000, φ=2.3000⟩
# Fidelity: 0.8631016271
# Creating Bloch sphere state |θ=1.8000, φ=2.4000⟩
# Fidelity: 0.9864566867
# Creating Bloch sphere state |θ=1.8000, φ=2.5000⟩
# Fidelity: 0.9818976691
# Creating Bloch sphere state |θ=1.8000, φ=2.6000⟩
# Fidelity: 0.9725236892
# Creating Bloch sphere state |θ=1.8000, φ=2.7000⟩
# Fidelity: 0.9584284086
# Creating Bloch sphere state |θ=1.8000, φ=2.8000⟩
# Fidelity: 0.9397526628
# Creating Bloch sphere state |θ=1.8000, φ=2.9000⟩
# Fidelity: 0.9166830537
# Creating Bloch sphere state |θ=1.8000, φ=3.0000⟩
# Fidelity: 0.8894500851
# Creating Bloch sphere state |θ=1.8000, φ=3.1000⟩
# Fidelity: 0.8583258599
# Creating Bloch sphere state |θ=1.9000, φ=0.0000⟩
# Fidelity: 0.9731500438
# Creating Bloch sphere state |θ=1.9000, φ=0.1000⟩
# Fidelity: 0.9707862644
# Creating Bloch sphere state |θ=1.9000, φ=0.2000⟩
# Fidelity: 0.9637185443
# Creating Bloch sphere state |θ=1.9000, φ=0.3000⟩
# Fidelity: 0.9520175017
# Creating Bloch sphere state |θ=1.9000, φ=0.4000⟩
# Fidelity: 0.9358000497
# Creating Bloch sphere state |θ=1.9000, φ=0.5000⟩
# Fidelity: 0.9152282276
# Creating Bloch sphere state |θ=1.9000, φ=0.6000⟩
# Fidelity: 0.8905075824
# Creating Bloch sphere state |θ=1.9000, φ=0.7000⟩
# Fidelity: 0.8618851144
# Creating Bloch sphere state |θ=1.9000, φ=0.8000⟩
# Fidelity: 0.9730995843
# Creating Bloch sphere state |θ=1.9000, φ=0.9000⟩
# Fidelity: 0.9700463464
# Creating Bloch sphere state |θ=1.9000, φ=1.0000⟩
# Fidelity: 0.9622965606
# Creating Bloch sphere state |θ=1.9000, φ=1.1000⟩
# Fidelity: 0.9499276603
# Creating Bloch sphere state |θ=1.9000, φ=1.2000⟩
# Fidelity: 0.9330632315
# Creating Bloch sphere state |θ=1.9000, φ=1.3000⟩
# Fidelity: 0.9118717778
# Creating Bloch sphere state |θ=1.9000, φ=1.4000⟩
# Fidelity: 0.8865650374
# Creating Bloch sphere state |θ=1.9000, φ=1.5000⟩
# Fidelity: 0.8573958669
# Creating Bloch sphere state |θ=1.9000, φ=1.6000⟩
# Fidelity: 0.9729482941
# Creating Bloch sphere state |θ=1.9000, φ=1.7000⟩
# Fidelity: 0.9692062485
# Creating Bloch sphere state |θ=1.9000, φ=1.8000⟩
# Fidelity: 0.9607760492
# Creating Bloch sphere state |θ=1.9000, φ=1.9000⟩
# Fidelity: 0.9477419280
# Creating Bloch sphere state |θ=1.9000, φ=2.0000⟩
# Fidelity: 0.9302341174
# Creating Bloch sphere state |θ=1.9000, φ=2.1000⟩
# Fidelity: 0.9084275497
# Creating Bloch sphere state |θ=1.9000, φ=2.2000⟩
# Fidelity: 0.8825401089
# Creating Bloch sphere state |θ=1.9000, φ=2.3000⟩
# Fidelity: 0.8528304538
# Creating Bloch sphere state |θ=1.9000, φ=2.4000⟩
# Fidelity: 0.9726961278
# Creating Bloch sphere state |θ=1.9000, φ=2.5000⟩
# Fidelity: 0.9682660726
# Creating Bloch sphere state |θ=1.9000, φ=2.6000⟩
# Fidelity: 0.9591572575
# Creating Bloch sphere state |θ=1.9000, φ=2.7000⟩
# Fidelity: 0.9454606947
# Creating Bloch sphere state |θ=1.9000, φ=2.8000⟩
# Fidelity: 0.9273132357
# Creating Bloch sphere state |θ=1.9000, φ=2.9000⟩
# Fidelity: 0.9048962041
# Creating Bloch sphere state |θ=1.9000, φ=3.0000⟩
# Fidelity: 0.8784335833
# Creating Bloch sphere state |θ=1.9000, φ=3.1000⟩
# Fidelity: 0.8481897792
# Creating Bloch sphere state |θ=2.0000, φ=0.0000⟩
# Fidelity: 0.9546487134
# Creating Bloch sphere state |θ=2.0000, φ=0.1000⟩
# Fidelity: 0.9523773636
# Creating Bloch sphere state |θ=2.0000, φ=0.2000⟩
# Fidelity: 0.9455860087
# Creating Bloch sphere state |θ=2.0000, φ=0.3000⟩
# Fidelity: 0.9343425057
# Creating Bloch sphere state |θ=2.0000, φ=0.4000⟩
# Fidelity: 0.9187591959
# Creating Bloch sphere state |θ=2.0000, φ=0.5000⟩
# Fidelity: 0.8989917827
# Creating Bloch sphere state |θ=2.0000, φ=0.6000⟩
# Fidelity: 0.8752377755
# Creating Bloch sphere state |θ=2.0000, φ=0.7000⟩
# Fidelity: 0.8477345164
# Creating Bloch sphere state |θ=2.0000, φ=0.8000⟩
# Fidelity: 0.9546002257
# Creating Bloch sphere state |θ=2.0000, φ=0.9000⟩
# Fidelity: 0.9516663769
# Creating Bloch sphere state |θ=2.0000, φ=1.0000⟩
# Fidelity: 0.9442196268
# Creating Bloch sphere state |θ=2.0000, φ=1.1000⟩
# Fidelity: 0.9323343810
# Creating Bloch sphere state |θ=2.0000, φ=1.2000⟩
# Fidelity: 0.9161293928
# Creating Bloch sphere state |θ=2.0000, φ=1.3000⟩
# Fidelity: 0.8957665771
# Creating Bloch sphere state |θ=2.0000, φ=1.4000⟩
# Fidelity: 0.8714493925
# Creating Bloch sphere state |θ=2.0000, φ=1.5000⟩
# Fidelity: 0.8434208082
# Creating Bloch sphere state |θ=2.0000, φ=1.6000⟩
# Fidelity: 0.9544548526
# Creating Bloch sphere state |θ=2.0000, φ=1.7000⟩
# Fidelity: 0.9508591302
# Creating Bloch sphere state |θ=2.0000, φ=1.8000⟩
# Fidelity: 0.9427585724
# Creating Bloch sphere state |θ=2.0000, φ=1.9000⟩
# Fidelity: 0.9302341174
# Creating Bloch sphere state |θ=2.0000, φ=2.0000⟩
# Fidelity: 0.9134109052
# Creating Bloch sphere state |θ=2.0000, φ=2.1000⟩
# Fidelity: 0.8924570280
# Creating Bloch sphere state |θ=2.0000, φ=2.2000⟩
# Fidelity: 0.8675818498
# Creating Bloch sphere state |θ=2.0000, φ=2.3000⟩
# Fidelity: 0.8390339153
# Creating Bloch sphere state |θ=2.0000, φ=2.4000⟩
# Fidelity: 0.9542125454
# Creating Bloch sphere state |θ=2.0000, φ=2.5000⟩
# Fidelity: 0.9499557162
# ...
# Creating Bloch sphere state |θ=2.5000, φ=0.2000⟩
# Fidelity: 0.9906210531
# Creating Bloch sphere state |θ=2.5000, φ=0.3000⟩
# Fidelity: 0.9853883712
# Creating Bloch sphere state |θ=2.5000, φ=0.4000⟩
# Fidelity: 0.9781359592
# Creating Bloch sphere state |θ=2.5000, φ=0.5000⟩
# Fidelity: 0.9689362807
# Creating Bloch sphere state |θ=2.5000, φ=0.6000⟩
# Fidelity: 0.9578812560
# Creating Bloch sphere state |θ=2.5000, φ=0.7000⟩
# Fidelity: 0.9450813431
# Creating Bloch sphere state |θ=2.5000, φ=0.8000⟩
# Fidelity: 0.9948162617
# Creating Bloch sphere state |θ=2.5000, φ=0.9000⟩
# Fidelity: 0.9934508620
# Creating Bloch sphere state |θ=2.5000, φ=1.0000⟩
# Fidelity: 0.9899851747
# Creating Bloch sphere state |θ=2.5000, φ=1.1000⟩
# Fidelity: 0.9844538276
# Creating Bloch sphere state |θ=2.5000, φ=1.2000⟩
# Fidelity: 0.9769120882
# Creating Bloch sphere state |θ=2.5000, φ=1.3000⟩
# Fidelity: 0.9674353111
# Creating Bloch sphere state |θ=2.5000, φ=1.4000⟩
# Fidelity: 0.9561181851
# Creating Bloch sphere state |θ=2.5000, φ=1.5000⟩
# Fidelity: 0.9430737872
# Creating Bloch sphere state |θ=2.5000, φ=1.6000⟩
# Fidelity: 0.9947485752
# Creating Bloch sphere state |θ=2.5000, φ=1.7000⟩
# Fidelity: 0.9930751423
# Creating Bloch sphere state |θ=2.5000, φ=1.8000⟩
# Fidelity: 0.9893051756
# Creating Bloch sphere state |θ=2.5000, φ=1.9000⟩
# Fidelity: 0.9834763433
# Creating Bloch sphere state |θ=2.5000, φ=2.0000⟩
# Fidelity: 0.9756468853
# Creating Bloch sphere state |θ=2.5000, φ=2.1000⟩
# Fidelity: 0.9658950308
# Creating Bloch sphere state |θ=2.5000, φ=2.2000⟩
# Fidelity: 0.9543182171
# Creating Bloch sphere state |θ=2.5000, φ=2.3000⟩
# Fidelity: 0.9410321161
# Creating Bloch sphere state |θ=2.5000, φ=2.4000⟩
# Fidelity: 0.9946358375
# Creating Bloch sphere state |θ=2.5000, φ=2.5000⟩
# Fidelity: 0.9926547277
# Creating Bloch sphere state |θ=2.5000, φ=2.6000⟩
# Fidelity: 0.9885812848
# Creating Bloch sphere state |θ=2.5000, φ=2.7000⟩
# Fidelity: 0.9824562094
# Creating Bloch sphere state |θ=2.5000, φ=2.8000⟩
# Fidelity: 0.9743407013
# Creating Bloch sphere state |θ=2.5000, φ=2.9000⟩
# Fidelity: 0.9643158479
# Creating Bloch sphere state |θ=2.5000, φ=3.0000⟩
# Fidelity: 0.9524818142
# Creating Bloch sphere state |θ=2.5000, φ=3.1000⟩
# Fidelity: 0.9389568421
# Creating Bloch sphere state |θ=2.6000, φ=0.0000⟩
# Fidelity: 0.9852130821
# Creating Bloch sphere state |θ=2.6000, φ=0.1000⟩
# Fidelity: 0.9843025576
# Creating Bloch sphere state |θ=2.6000, φ=0.2000⟩
# Fidelity: 0.9815800768
# Creating Bloch sphere state |θ=2.6000, φ=0.3000⟩
# Fidelity: 0.9770728416
# Creating Bloch sphere state |θ=2.6000, φ=0.4000⟩
# Fidelity: 0.9708258869
# Creating Bloch sphere state |θ=2.6000, φ=0.5000⟩
# Fidelity: 0.9629016303
# Creating Bloch sphere state |θ=2.6000, φ=0.6000⟩
# Fidelity: 0.9533792482
# Creating Bloch sphere state |θ=2.6000, φ=0.7000⟩
# Fidelity: 0.9423538851
# Creating Bloch sphere state |θ=2.6000, φ=0.8000⟩
# Fidelity: 0.9851936747
# Creating Bloch sphere state |θ=2.6000, φ=0.9000⟩
# Fidelity: 0.9840175708
# Creating Bloch sphere state |θ=2.6000, φ=1.0000⟩
# Fidelity: 0.9810323582
# Creating Bloch sphere state |θ=2.6000, φ=1.1000⟩
# Fidelity: 0.9762678641
# Creating Bloch sphere state |θ=2.6000, φ=1.2000⟩
# Fidelity: 0.9697716938
# Creating Bloch sphere state |θ=2.6000, φ=1.3000⟩
# Fidelity: 0.9616087548
# Creating Bloch sphere state |θ=2.6000, φ=1.4000⟩
# Fidelity: 0.9518606085
# Creating Bloch sphere state |θ=2.6000, φ=1.5000⟩
# Fidelity: 0.9406246553
# Creating Bloch sphere state |θ=2.6000, φ=1.6000⟩
# Fidelity: 0.9851353689
# Creating Bloch sphere state |θ=2.6000, φ=1.7000⟩
# Fidelity: 0.9836939368
# Creating Bloch sphere state |θ=2.6000, φ=1.8000⟩
# Fidelity: 0.9804466294
# Creating Bloch sphere state |θ=2.6000, φ=1.9000⟩
# Fidelity: 0.9754258927
# Creating Bloch sphere state |θ=2.6000, φ=2.0000⟩
# Fidelity: 0.9686818924
# Creating Bloch sphere state |θ=2.6000, φ=2.1000⟩
# Fidelity: 0.9602820121
# Creating Bloch sphere state |θ=2.6000, φ=2.2000⟩
# Fidelity: 0.9503101807
# Creating Bloch sphere state |θ=2.6000, φ=2.3000⟩
# Fidelity: 0.9388660335
# Creating Bloch sphere state |θ=2.6000, φ=2.4000⟩
# Fidelity: 0.9850382641
# Creating Bloch sphere state |θ=2.6000, φ=2.5000⟩
# Fidelity: 0.9833318106
# Creating Bloch sphere state |θ=2.6000, φ=2.6000⟩
# Fidelity: 0.9798231003
# Creating Bloch sphere state |θ=2.6000, φ=2.7000⟩
# Fidelity: 0.9745471910
# Creating Bloch sphere state |θ=2.6000, φ=2.8000⟩
# Fidelity: 0.9675567979
# Creating Bloch sphere state |θ=2.6000, φ=2.9000⟩
# Fidelity: 0.9589217666
# Creating Bloch sphere state |θ=2.6000, φ=3.0000⟩
# Fidelity: 0.9487283756
# Creating Bloch sphere state |θ=2.6000, φ=3.1000⟩
# Fidelity: 0.9370784738
# Creating Bloch sphere state |θ=2.7000, φ=0.0000⟩
# Fidelity: 0.9707392784
# Creating Bloch sphere state |θ=2.7000, φ=0.1000⟩
# Fidelity: 0.9699844020
# Creating Bloch sphere state |θ=2.7000, φ=0.2000⟩
# Fidelity: 0.9677273110
# Creating Bloch sphere state |θ=2.7000, φ=0.3000⟩
# Fidelity: 0.9639905573
# Creating Bloch sphere state |θ=2.7000, φ=0.4000⟩
# Fidelity: 0.9588114775
# Creating Bloch sphere state |θ=2.7000, φ=0.5000⟩
# Fidelity: 0.9522418192
# Creating Bloch sphere state |θ=2.7000, φ=0.6000⟩
# Fidelity: 0.9443472243
# Creating Bloch sphere state |θ=2.7000, φ=0.7000⟩
# Fidelity: 0.9352065729
# Creating Bloch sphere state |θ=2.7000, φ=0.8000⟩
# Fidelity: 0.9707231925
# Creating Bloch sphere state |θ=2.7000, φ=0.9000⟩
# Fidelity: 0.9697481356
# Creating Bloch sphere state |θ=2.7000, φ=1.0000⟩
# Fidelity: 0.9672732250
# Creating Bloch sphere state |θ=2.7000, φ=1.1000⟩
# Fidelity: 0.9633231891
# Creating Bloch sphere state |θ=2.7000, φ=1.2000⟩
# Fidelity: 0.9579374954
# Creating Bloch sphere state |θ=2.7000, φ=1.3000⟩
# Fidelity: 0.9511699559
# Creating Bloch sphere state |θ=2.7000, φ=1.4000⟩
# Fidelity: 0.9430881897
# Creating Bloch sphere state |θ=2.7000, φ=1.5000⟩
# Fidelity: 0.9337729471
# Creating Bloch sphere state |θ=2.7000, φ=1.6000⟩
# Fidelity: 0.9706748498
# Creating Bloch sphere state |θ=2.7000, φ=1.7000⟩
# Fidelity: 0.9694798208
# Creating Bloch sphere state |θ=2.7000, φ=1.8000⟩
# Fidelity: 0.9667876188
# Creating Bloch sphere state |θ=2.7000, φ=1.9000⟩
# Fidelity: 0.9626251433
# Creating Bloch sphere state |θ=2.7000, φ=2.0000⟩
# Fidelity: 0.9570339844
# Creating Bloch sphere state |θ=2.7000, φ=2.1000⟩
# Fidelity: 0.9500700071
# Creating Bloch sphere state |θ=2.7000, φ=2.2000⟩
# Fidelity: 0.9418027932
# Creating Bloch sphere state |θ=2.7000, φ=2.3000⟩
# Fidelity: 0.9323149460
# Creating Bloch sphere state |θ=2.7000, φ=2.4000⟩
# Fidelity: 0.9705943483
# Creating Bloch sphere state |θ=2.7000, φ=2.5000⟩
# Fidelity: 0.9691796016
# Creating Bloch sphere state |θ=2.7000, φ=2.6000⟩
# Fidelity: 0.9662706817
# Creating Bloch sphere state |θ=2.7000, φ=2.7000⟩
# Fidelity: 0.9618966536
# Creating Bloch sphere state |θ=2.7000, φ=2.8000⟩
# Fidelity: 0.9561012211
# Creating Bloch sphere state |θ=2.7000, φ=2.9000⟩
# Fidelity: 0.9489422903
# Creating Bloch sphere state |θ=2.7000, φ=3.0000⟩
# Fidelity: 0.9404913909
# Creating Bloch sphere state |θ=2.7000, φ=3.1000⟩
# Fidelity: 0.9308329615
# Creating Bloch sphere state |θ=2.8000, φ=0.0000⟩
# Fidelity: 0.9515620030
# Creating Bloch sphere state |θ=2.8000, φ=0.1000⟩
# Fidelity: 0.9509703171
# Creating Bloch sphere state |θ=2.8000, φ=0.2000⟩
# Fidelity: 0.9492011680
# Creating Bloch sphere state |θ=2.8000, φ=0.3000⟩
# Fidelity: 0.9462722323
# Creating Bloch sphere state |θ=2.8000, φ=0.4000⟩
# Fidelity: 0.9422127750
# Creating Bloch sphere state |θ=2.8000, φ=0.5000⟩
# Fidelity: 0.9370633569
# Creating Bloch sphere state |θ=2.8000, φ=0.6000⟩
# Fidelity: 0.9308754293
# Creating Bloch sphere state |θ=2.8000, φ=0.7000⟩
# Fidelity: 0.9237108199
# Creating Bloch sphere state |θ=2.8000, φ=0.8000⟩
# Fidelity: 0.9515493993
# Creating Bloch sphere state |θ=2.8000, φ=0.9000⟩
# Fidelity: 0.9507851320
# Creating Bloch sphere state |θ=2.8000, φ=1.0000⟩
# Fidelity: 0.9488452519
# Creating Bloch sphere state |θ=2.8000, φ=1.1000⟩
# Fidelity: 0.9457491416
# Creating Bloch sphere state |θ=2.8000, φ=1.2000⟩
# Fidelity: 0.9415277366
# Creating Bloch sphere state |θ=2.8000, φ=1.3000⟩
# Fidelity: 0.9362232156
# Creating Bloch sphere state |θ=2.8000, φ=1.4000⟩
# Fidelity: 0.9298885798
# Creating Bloch sphere state |θ=2.8000, φ=1.5000⟩
# Fidelity: 0.9225871226
# Creating Bloch sphere state |θ=2.8000, φ=1.6000⟩
# Fidelity: 0.9515115027
# Creating Bloch sphere state |θ=2.8000, φ=1.7000⟩
# Fidelity: 0.9505748172
# Creating Bloch sphere state |θ=2.8000, φ=1.8000⟩
# Fidelity: 0.9484646201
# Creating Bloch sphere state |θ=2.8000, φ=1.9000⟩
# Fidelity: 0.9452019958
# Creating Bloch sphere state |θ=2.8000, φ=2.0000⟩
# Fidelity: 0.9408195434
# Creating Bloch sphere state |θ=2.8000, φ=2.1000⟩
# Fidelity: 0.9353610510
# Creating Bloch sphere state |θ=2.8000, φ=2.2000⟩
# Fidelity: 0.9288810578
# Creating Bloch sphere state |θ=2.8000, φ=2.3000⟩
# Fidelity: 0.9214443100
# Creating Bloch sphere state |θ=2.8000, φ=2.4000⟩
# Fidelity: 0.9514484089
# Creating Bloch sphere state |θ=2.8000, φ=2.5000⟩
# Fidelity: 0.9503395046
# Creating Bloch sphere state |θ=2.8000, φ=2.6000⟩
# Fidelity: 0.9480594401
# Creating Bloch sphere state |θ=2.8000, φ=2.7000⟩
# Fidelity: 0.9446309970
# Creating Bloch sphere state |θ=2.8000, φ=2.8000⟩
# Fidelity: 0.9400884313
# Creating Bloch sphere state |θ=2.8000, φ=2.9000⟩
# Fidelity: 0.9344771307
# Creating Bloch sphere state |θ=2.8000, φ=3.0000⟩
# Fidelity: 0.9278531615
# Creating Bloch sphere state |θ=2.8000, φ=3.1000⟩
# Fidelity: 0.9202827082
# Creating Bloch sphere state |θ=2.9000, φ=0.0000⟩
# Fidelity: 0.9278728689
# Creating Bloch sphere state |θ=2.9000, φ=0.1000⟩
# Fidelity: 0.9274502854
# Creating Bloch sphere state |θ=2.9000, φ=0.2000⟩
# Fidelity: 0.9261867549
# Creating Bloch sphere state |θ=2.9000, φ=0.3000⟩
# Fidelity: 0.9240949021
# Creating Bloch sphere state |θ=2.9000, φ=0.4000⟩
# Fidelity: 0.9211956281
# Creating Bloch sphere state |θ=2.9000, φ=0.5000⟩
# Fidelity: 0.9175179015
# Creating Bloch sphere state |θ=2.9000, φ=0.6000⟩
# Fidelity: 0.9130984690
# Creating Bloch sphere state |θ=2.9000, φ=0.7000⟩
# Fidelity: 0.9079814880
# Creating Bloch sphere state |θ=2.9000, φ=0.8000⟩
# Fidelity: 0.9278638734
# Creating Bloch sphere state |θ=2.9000, φ=0.9000⟩
# Fidelity: 0.9273180319
# Creating Bloch sphere state |θ=2.9000, φ=1.0000⟩
# Fidelity: 0.9259325649
# Creating Bloch sphere state |θ=2.9000, φ=1.1000⟩
# Fidelity: 0.9237213157
# Creating Bloch sphere state |θ=2.9000, φ=1.2000⟩
# Fidelity: 0.9207063782
# Creating Bloch sphere state |θ=2.9000, φ=1.3000⟩
# Fidelity: 0.9169178768
# Creating Bloch sphere state |θ=2.9000, φ=1.4000⟩
# Fidelity: 0.9123936649
# Creating Bloch sphere state |θ=2.9000, φ=1.5000⟩
# Fidelity: 0.9071789469
# Creating Bloch sphere state |θ=2.9000, φ=1.6000⟩
# Fidelity: 0.9278368014
# Creating Bloch sphere state |θ=2.9000, φ=1.7000⟩
# Fidelity: 0.9271678184
# Creating Bloch sphere state |θ=2.9000, φ=1.8000⟩
# Fidelity: 0.9256607106
# Creating Bloch sphere state |θ=2.9000, φ=1.9000⟩
# Fidelity: 0.9233305367
# Creating Bloch sphere state |θ=2.9000, φ=2.0000⟩
# Fidelity: 0.9202005788
# Creating Bloch sphere state |θ=2.9000, φ=2.1000⟩
# Fidelity: 0.9163021106
# Creating Bloch sphere state |θ=2.9000, φ=2.2000⟩
# Fidelity: 0.9116740841
# Creating Bloch sphere state |θ=2.9000, φ=2.3000⟩
# Fidelity: 0.9063627413
# Creating Bloch sphere state |θ=2.9000, φ=2.4000⟩
# Fidelity: 0.9277917458
# Creating Bloch sphere state |θ=2.9000, φ=2.5000⟩
# Fidelity: 0.9269997637
# Creating Bloch sphere state |θ=2.9000, φ=2.6000⟩
# Fidelity: 0.9253713363
# Creating Bloch sphere state |θ=2.9000, φ=2.7000⟩
# Fidelity: 0.9229227341
# Creating Bloch sphere state |θ=2.9000, φ=2.8000⟩
# Fidelity: 0.9196784229
# Creating Bloch sphere state |θ=2.9000, φ=2.9000⟩
# Fidelity: 0.9156708188
# Creating Bloch sphere state |θ=2.9000, φ=3.0000⟩
# Fidelity: 0.9109399643
# Creating Bloch sphere state |θ=2.9000, φ=3.1000⟩
# Fidelity: 0.9055331287
# Creating Bloch sphere state |θ=3.0000, φ=0.0000⟩
# Fidelity: 0.8999085699
# Creating Bloch sphere state |θ=3.0000, φ=0.1000⟩
# Fidelity: 0.8996593112
# Creating Bloch sphere state |θ=3.0000, φ=0.2000⟩
# Fidelity: 0.8989140241
# Creating Bloch sphere state |θ=3.0000, φ=0.3000⟩
# Fidelity: 0.8976801553
# Creating Bloch sphere state |θ=3.0000, φ=0.4000⟩
# Fidelity: 0.8959700332
# Creating Bloch sphere state |θ=3.0000, φ=0.5000⟩
# Fidelity: 0.8938007447
# Creating Bloch sphere state |θ=3.0000, φ=0.6000⟩
# Fidelity: 0.8911939648
# Creating Bloch sphere state |θ=3.0000, φ=0.7000⟩
# Fidelity: 0.8881757394
# Creating Bloch sphere state |θ=3.0000, φ=0.8000⟩
# Fidelity: 0.8999032727
# Creating Bloch sphere state |θ=3.0000, φ=0.9000⟩
# Fidelity: 0.8995813108
# Creating Bloch sphere state |θ=3.0000, φ=1.0000⟩
# Fidelity: 0.8987641001
# Creating Bloch sphere state |θ=3.0000, φ=1.1000⟩
# Fidelity: 0.8974598059
# Creating Bloch sphere state |θ=3.0000, φ=1.2000⟩
# Fidelity: 0.8956814603
# Creating Bloch sphere state |θ=3.0000, φ=1.3000⟩
# Fidelity: 0.8934468319
# Creating Bloch sphere state |θ=3.0000, φ=1.4000⟩
# Fidelity: 0.8907782484
# Creating Bloch sphere state |θ=3.0000, φ=1.5000⟩
# Fidelity: 0.8877023733
# Creating Bloch sphere state |θ=3.0000, φ=1.6000⟩
# Fidelity: 0.8998872957
# Creating Bloch sphere state |θ=3.0000, φ=1.7000⟩
# Fidelity: 0.8994926994
# Creating Bloch sphere state |θ=3.0000, φ=1.8000⟩
# Fidelity: 0.8986037396
# Creating Bloch sphere state |θ=3.0000, φ=1.9000⟩
# Fidelity: 0.8972292982
# Creating Bloch sphere state |θ=3.0000, φ=2.0000⟩
# Fidelity: 0.8953831084
# Creating Bloch sphere state |θ=3.0000, φ=2.1000⟩
# Fidelity: 0.8930836166
# Creating Bloch sphere state |θ=3.0000, φ=2.2000⟩
# Fidelity: 0.8903537986
# Creating Bloch sphere state |θ=3.0000, φ=2.3000⟩
# Fidelity: 0.8872209298
# Creating Bloch sphere state |θ=3.0000, φ=2.4000⟩
# Fidelity: 0.8998607286
# Creating Bloch sphere state |θ=3.0000, φ=2.5000⟩
# Fidelity: 0.8993935820
# Creating Bloch sphere state |θ=3.0000, φ=2.6000⟩
# Fidelity: 0.8984330623
# Creating Bloch sphere state |θ=3.0000, φ=2.7000⟩
# Fidelity: 0.8969887667
# Creating Bloch sphere state |θ=3.0000, φ=2.8000⟩
# Fidelity: 0.8950751261
# Creating Bloch sphere state |θ=3.0000, φ=2.9000⟩
# Fidelity: 0.8927112610
# Creating Bloch sphere state |θ=3.0000, φ=3.0000⟩
# Fidelity: 0.8899207904
# Creating Bloch sphere state |θ=3.0000, φ=3.1000⟩
# Fidelity: 0.8867315957
# Creating Bloch sphere state |θ=3.1000, φ=0.0000⟩
# Fidelity: 0.8679485162
# Creating Bloch sphere state |θ=3.1000, φ=0.1000⟩
# Fidelity: 0.8678750727
# Creating Bloch sphere state |θ=3.1000, φ=0.2000⟩
# Fidelity: 0.8676554757
# Creating Bloch sphere state |θ=3.1000, φ=0.3000⟩
# Fidelity: 0.8672919193
# Creating Bloch sphere state |θ=3.1000, φ=0.4000⟩
# Fidelity: 0.8667880361
# Creating Bloch sphere state |θ=3.1000, φ=0.5000⟩
# Fidelity: 0.8661488606
# Creating Bloch sphere state |θ=3.1000, φ=0.6000⟩
# Fidelity: 0.8653807793
# Creating Bloch sphere state |θ=3.1000, φ=0.7000⟩
# Fidelity: 0.8644914666
# Creating Bloch sphere state |θ=3.1000, φ=0.8000⟩
# Fidelity: 0.8679469703
# Creating Bloch sphere state |θ=3.1000, φ=0.9000⟩
# Fidelity: 0.8678521050
# Creating Bloch sphere state |θ=3.1000, φ=1.0000⟩
# Fidelity: 0.8676113159
# Creating Bloch sphere state |θ=3.1000, φ=1.1000⟩
# Fidelity: 0.8672270088
# Creating Bloch sphere state |θ=3.1000, φ=1.2000⟩
# Fidelity: 0.8667030237
# Creating Bloch sphere state |θ=3.1000, φ=1.3000⟩
# Fidelity: 0.8660445959
# Creating Bloch sphere state |θ=3.1000, φ=1.4000⟩
# Fidelity: 0.8652583044
# Creating Bloch sphere state |θ=3.1000, φ=1.5000⟩
# Fidelity: 0.8643520054
# Creating Bloch sphere state |θ=3.1000, φ=1.6000⟩
# Fidelity: 0.8679422478
# Creating Bloch sphere state |θ=3.1000, φ=1.7000⟩
# Fidelity: 0.8678259810
# Creating Bloch sphere state |θ=3.1000, φ=1.8000⟩
# Fidelity: 0.8675640512
# Creating Bloch sphere state |θ=3.1000, φ=1.9000⟩
# Fidelity: 0.8671590754
# Creating Bloch sphere state |θ=3.1000, φ=2.0000⟩
# Fidelity: 0.8666151001
# Creating Bloch sphere state |θ=3.1000, φ=2.1000⟩
# Fidelity: 0.8659375605
# Creating Bloch sphere state |θ=3.1000, φ=2.2000⟩
# Fidelity: 0.8651332264
# Creating Bloch sphere state |θ=3.1000, φ=2.3000⟩
# Fidelity: 0.8642101343
# Creating Bloch sphere state |θ=3.1000, φ=2.4000⟩
# Fidelity: 0.8679344348
# Creating Bloch sphere state |θ=3.1000, φ=2.5000⟩
# Fidelity: 0.8677967912
# Creating Bloch sphere state |θ=3.1000, φ=2.6000⟩
# Fidelity: 0.8675137764
# Creating Bloch sphere state |θ=3.1000, φ=2.7000⟩
# Fidelity: 0.8670882183
# Creating Bloch sphere state |θ=3.1000, φ=2.8000⟩
# Fidelity: 0.8665243688
# Creating Bloch sphere state |θ=3.1000, φ=2.9000⟩
# Fidelity: 0.8658278618
# Creating Bloch sphere state |θ=3.1000, φ=3.0000⟩
# Fidelity: 0.8650056565
# Creating Bloch sphere state |θ=3.1000, φ=3.1000⟩
# Fidelity: 0.8640659681

# %%
import numpy as np
from typing import Dict, Tuple

def create_bloch_state(theta: float, phi: float) -> np.ndarray:
    """
    Create the Bloch sphere state |θ,φ⟩.
    
    |θ,φ⟩ = cos(θ/2)|0⟩ + e^(iφ)sin(θ/2)|1⟩
    
    Args:
        theta: Polar angle (0 to π)
        phi: Azimuthal angle (0 to 2π)
    
    Returns:
        State vector as numpy array
    """
    state = np.array([
        np.cos(theta/2),
        np.exp(1j * phi) * np.sin(theta/2)
    ], dtype=complex)
    
    return state

def get_clifford_basis_states() -> Dict[str, np.ndarray]:
    """
    Return the 6 Clifford basis states:
    |0⟩, |1⟩, |+⟩, |-⟩, |i⟩, |-i⟩
    """
    states = {
        '|0⟩': np.array([1, 0], dtype=complex),
        '|1⟩': np.array([0, 1], dtype=complex),
        '|+⟩': np.array([1, 1], dtype=complex) / np.sqrt(2),
        '|-⟩': np.array([1, -1], dtype=complex) / np.sqrt(2),
        '|i⟩': np.array([1, 1j], dtype=complex) / np.sqrt(2),
        '|-i⟩': np.array([1, -1j], dtype=complex) / np.sqrt(2),
    }
    return states

def compute_fidelity(state1: np.ndarray, state2: np.ndarray) -> float:
    """
    Compute fidelity between two quantum states.
    Fidelity = |⟨ψ|φ⟩|²
    """
    return abs(np.dot(np.conj(state1), state2))

def compute_clifford_fidelities(theta: float, phi: float) -> Dict[str, float]:
    """
    Compute fidelities of |θ,φ⟩ with all 6 Clifford basis states.
    
    Args:
        theta: Polar angle
        phi: Azimuthal angle
    
    Returns:
        Dictionary mapping Clifford state names to fidelities
    """
    # Create the Bloch state
    bloch_state = create_bloch_state(theta, phi)
    
    # Get Clifford basis states
    clifford_states = get_clifford_basis_states()
    
    # Compute fidelities
    fidelities = {}
    for name, clifford_state in clifford_states.items():
        fid = compute_fidelity(bloch_state, clifford_state)
        fidelities[name] = fid
    
    return fidelities

def find_minimum_clifford_distance(theta: float, phi: float) -> Tuple[str, float]:
    """
    Find the Clifford state with minimum fidelity to |θ,φ⟩.
    
    Returns:
        (state_name, min_fidelity)
    """
    fidelities = compute_clifford_fidelities(theta, phi)
    print(fidelities)
    
    # Find minimum
    min_state = min(fidelities, key=fidelities.get)
    min_fidelity = fidelities[min_state]
    
    return min_state, min_fidelity

def analyze_state(theta: float, phi: float):
    """
    Complete analysis showing all fidelities and the minimum.
    """
    # Create the state
    state = create_bloch_state(theta, phi)
    
    print(f"Bloch Sphere State: |θ={theta:.4f}, φ={phi:.4f}⟩")
    print(f"State vector: [{state[0]:.6f}, {state[1]:.6f}]")
    print(f"{'='*70}")
    
    # Compute fidelities
    fidelities = compute_clifford_fidelities(theta, phi)
    
    # Find minimum
    min_state, min_fidelity = find_minimum_clifford_distance(theta, phi)
    
    print(f"Fidelities with Clifford Basis States:")
    print(f"{'-'*70}")
    
    # Sort by fidelity (highest to lowest)
    sorted_fidelities = sorted(fidelities.items(), key=lambda x: x[1], reverse=True)
    
    for name, fid in sorted_fidelities:
        marker = " ← MINIMUM" if name == min_state else ""
        print(f"{name:6s}: {fid:.10f}{marker}")
    
    print(f"{'-'*70}")
    print(f"Minimum fidelity: {min_state} with fidelity = {min_fidelity:.10f}")
    print(f"{'='*70}")
    
    return fidelities, min_state, min_fidelity

# Example usage
if __name__ == "__main__":
    # Example 1: A general state
    print("Example 1: General State")
    theta1 = np.pi / 3
    phi1 = np.pi / 4
    analyze_state(theta1, phi1)
    
    print("\n" * 2)
    
    # Example 2: The |+⟩ state (should have fidelity 1 with |+⟩)
    print("Example 2: |+⟩ State (θ=π/2, φ=0)")
    theta2 = np.pi / 2
    phi2 = 0
    analyze_state(theta2, phi2)
    
    print("\n" * 2)
    
    # Example 3: The |i⟩ state (should have fidelity 1 with |i⟩)
    print("Example 3: |i⟩ State (θ=π/2, φ=π/2)")
    theta3 = np.pi / 2
    phi3 = np.pi / 2
    analyze_state(theta3, phi3)
    
    print("\n" * 2)
    
    # Example 4: A magic state (low overlap with all Clifford states)
    print("Example 4: Magic State (θ=π/4, φ=π/8)")
    theta4 = np.pi / 4
    phi4 = np.pi / 8
    analyze_state(theta4, phi4)
    
    print("\n" * 2)
    
    # Example 5: Just get the minimum
    print("Example 5: Quick minimum fidelity check")
    theta5 = 2 * np.pi / 5
    phi5 = 3 * np.pi / 7
    min_state, min_fid = find_minimum_clifford_distance(theta5, phi5)
    print(f"For θ={theta5:.4f}, φ={phi5:.4f}:")
    print(f"Minimum Clifford fidelity: {min_state} = {min_fid:.10f}")
# Out:
# Example 1: General State
# Bloch Sphere State: |θ=1.0472, φ=0.7854⟩
# State vector: [0.866025+0.000000j, 0.353553+0.353553j]
# ======================================================================
# {'|0⟩': np.float64(0.8660254037844387), '|1⟩': np.float64(0.4999999999999999), '|+⟩': np.float64(0.8978787322617109), '|-⟩': np.float64(0.44024286723591866), '|i⟩': np.float64(0.8978787322617109), '|-i⟩': np.float64(0.4402428672359187)}
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'dict' object has no attribute 'arccos'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 126
#     124 theta1 = np.pi / 3
#     125 phi1 = np.pi / 4
# --> 126 analyze_state(theta1, phi1)
#     128 print("\n" * 2)
#     130 # Example 2: The |+⟩ state (should have fidelity 1 with |+⟩)
#
# Cell In[23], line 102, in analyze_state(theta, phi)
#      99 fidelities = compute_clifford_fidelities(theta, phi)
#     101 # Find minimum
# --> 102 min_state, min_fidelity = find_minimum_clifford_distance(theta, phi)
#     104 print(f"Fidelities with Clifford Basis States:")
#     105 print(f"{'-'*70}")
#
# Cell In[23], line 82, in find_minimum_clifford_distance(theta, phi)
#      79 print(fidelities)
#      81 # Find minimum
# ---> 82 min_state = min(np.arccos(fidelities), key=fidelities.get)
#      83 min_fidelity = fidelities[min_state]
#      85 return min_state, min_fidelity
#
# TypeError: loop of ufunc does not support argument 0 of type dict which has no callable arccos method
